# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pdfplumber
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pdfplumber in /usr/local/lib/python3.7/dist-packages (0.7.6)
# Requirement already satisfied: pdfminer.six==20221105 in /usr/local/lib/python3.7/dist-packages (from pdfplumber) (20221105)
# Requirement already satisfied: Wand>=0.6.10 in /usr/local/lib/python3.7/dist-packages (from pdfplumber) (0.6.10)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.7/dist-packages (from pdfplumber) (9.3.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from pdfminer.six==20221105->pdfplumber) (2.1.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from pdfminer.six==20221105->pdfplumber) (4.1.1)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.7/dist-packages (from pdfminer.six==20221105->pdfplumber) (38.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber) (2.21)

# %%
# !pip install ocrmypdf -q   #installing OCR library

# %%
import pdfplumber
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords 
from string import punctuation
from nltk.corpus import wordnet as wn
from nltk.stem import WordNetLemmatizer
from nltk.probability import FreqDist
from heapq import nlargest
from collections import defaultdict
import pandas as pd 
from nltk.collocations import *
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
with pdfplumber.open("test.pdf") as pdf:
    text=""
    pages = pdf.pages
    for page in pages:
        text += page.extract_text(x_tolerance=2)
        print(text)
# Out:
# Anudeep
# Sr Java Programmer
# anudeepreddynallamada@gmail.com
# PROFESSIONAL SUMMARY:
# • IT professional with 8+ years of IT experience in designing and developing N-tier applications based on
# OOPS (Object Oriented Programming), Internet and Intranet, Client-Server Architecture using Java/J2EE
# and supporting technologies.
# •  Strong Experience in developing user interfaces with HTML, DHTML, XML and CSS.
# • Experienced in processing, validating, parsing and extracting data from .xml file.
# •  Worked with scripting languages like JavaScript, JQuery.
# •  Well versed in MVC (Model View Controller) architecture using Spring, JSF and implementing JSTL (JSP
# Standard Tag Library), custom tag development and tiles.
# •  Experience in JSP, Java Beans and Servlets for developing applications using MVC architecture.
# •  Good exposure in implementing web services-WSDL using SOAP protocol.
# •  Experienced in Persistence Framework like Hibernate ORM (Object Relational Mapping) in a typical n-
# tier architecture.
# • Experienced in build tools like ANT and Maven.
# • Experienced in using testing Frameworks like JUnit and JMockit.
# • Experienced in using logging tools like Intellij and Log4j.
# • Hands  on  experience  on Web/Application  servers  such  as Apache Tomcat,  JBoss, WebLogic  and Web
# Sphere.
# • Experienced in developing various UML designs like class diagrams, cases and sequence diagrams using
# Rational Rose.
# • Worked  on  different  platforms  like Windows  2003  Server, Windows  2000  Professional, Windows  XP,
# Windows […] UNIX and LINUX.
# • Experience in using UML like Rational Rose and MS Visio
# • Well versed in using version control tools like SVN, Clear Case and CVS.
# • Strong experience in using IDEs like Eclipse, NetBeans and RAD
# • Developed projects and products using Agile Methodology, SDLC (Software development life cycle), from
# initiation, planning, designing, execution, implementation and Maintenance.
# EDUCATION:
# Bachelor of Engineering in Computer Science and Engineering        JNTU, Hyderabad, India.     2009
# TECHNICAL SKILLS:
# Languages C, C++, JAVA/J2EE, PL/SQL, Shell script, UNIX commands.
# Java Technologies Core  Java,  J2EE,  JSP,  Servlet,  JDBC,  JMS,  JavaBeans,  JNDI,  Java  Mail,
# Java1.8.
# Web Technologies AngularJS, jQuery, JavaScript, HTML, DHTML, XML,
# Cascading Style Sheets (CSS), XSLT.
# XML Technologies XML Schema, DTD, JAXP, SAX and DOM parsers.
# IDEs / Tools  Eclipse, NetBeans, Red Hat Developer Studio, RAD, WSAD. / TOAD, Maven,
# XmlSpy, Ant, PL/SQ L Developer, JUnit, iReport.
# Anudeep
# Sr Java Programmer
# anudeepreddynallamada@gmail.com
# PROFESSIONAL SUMMARY:
# • IT professional with 8+ years of IT experience in designing and developing N-tier applications based on
# OOPS (Object Oriented Programming), Internet and Intranet, Client-Server Architecture using Java/J2EE
# and supporting technologies.
# •  Strong Experience in developing user interfaces with HTML, DHTML, XML and CSS.
# • Experienced in processing, validating, parsing and extracting data from .xml file.
# •  Worked with scripting languages like JavaScript, JQuery.
# •  Well versed in MVC (Model View Controller) architecture using Spring, JSF and implementing JSTL (JSP
# Standard Tag Library), custom tag development and tiles.
# •  Experience in JSP, Java Beans and Servlets for developing applications using MVC architecture.
# •  Good exposure in implementing web services-WSDL using SOAP protocol.
# •  Experienced in Persistence Framework like Hibernate ORM (Object Relational Mapping) in a typical n-
# tier architecture.
# • Experienced in build tools like ANT and Maven.
# • Experienced in using testing Frameworks like JUnit and JMockit.
# • Experienced in using logging tools like Intellij and Log4j.
# • Hands  on  experience  on Web/Application  servers  such  as Apache Tomcat,  JBoss, WebLogic  and Web
# Sphere.
# • Experienced in developing various UML designs like class diagrams, cases and sequence diagrams using
# Rational Rose.
# • Worked  on  different  platforms  like Windows  2003  Server, Windows  2000  Professional, Windows  XP,
# Windows […] UNIX and LINUX.
# • Experience in using UML like Rational Rose and MS Visio
# • Well versed in using version control tools like SVN, Clear Case and CVS.
# • Strong experience in using IDEs like Eclipse, NetBeans and RAD
# • Developed projects and products using Agile Methodology, SDLC (Software development life cycle), from
# initiation, planning, designing, execution, implementation and Maintenance.
# EDUCATION:
# Bachelor of Engineering in Computer Science and Engineering        JNTU, Hyderabad, India.     2009
# TECHNICAL SKILLS:
# Languages C, C++, JAVA/J2EE, PL/SQL, Shell script, UNIX commands.
# Java Technologies Core  Java,  J2EE,  JSP,  Servlet,  JDBC,  JMS,  JavaBeans,  JNDI,  Java  Mail,
# Java1.8.
# Web Technologies AngularJS, jQuery, JavaScript, HTML, DHTML, XML,
# Cascading Style Sheets (CSS), XSLT.
# XML Technologies XML Schema, DTD, JAXP, SAX and DOM parsers.
# IDEs / Tools  Eclipse, NetBeans, Red Hat Developer Studio, RAD, WSAD. / TOAD, Maven,
# XmlSpy, Ant, PL/SQ L Developer, JUnit, iReport.Operating Systems Windows 95/98/NT/2000/XP, Sun Solaris 9/10, Red Hat Linux 9.
# Design Patterns MVC,  DAO,  DTO,  Front  Controller,  Session  Façade,  Business  Delegate,
# Observer, Singleton, View Helper, Decorator, Factory Pattern, POM, object pool
# Databases and Tools Oracle8  /  9i  /10g,11g,  HSQL,  Sybase,  MySQL,  MSSQL,  MongoDB,  SQL
# Server, IBM DB2, Toad for SQL Server.
# Frameworks Struts, Spring (Dependency Injection, Spring Core, Spring MVC, Spring AOP,
# Spring  DAO,  Spring  IOC,  Spring  JDBC,  Spring  with  Hibernate),  Hibernate,
# DWR, Log4j.
# Web service specifications and  JAX-RPC, JAX-WS, JAX-RS, ESB, Axis, JWSDP, RESTful webservices.
# Implementations
# Methodologies Agile, Scrum, Test Driven Development.
# Scripting/GUI Tools HTML5, DHTML, DOJO, JSON, JavaScript, CSS3, Shell Script, Dreamweaver,
# MS FrontPage, VBScript, JSTL, JSP, NodeJS
# Additional Skills Elasticsearch, Logstash, Kibana, Graphana, Git, Bitbucket, Maven, Jenkins.
# PROFESSIONAL EXPERIENCE:
# WIND STREAM COMMUNICATION, DALLAS, TX                                                                SEP-2016 -TILL DATE
# Role: Sr Java Programmer
# Responsibilities:
# • Involved in the application development using Java platform. Model View Control (MVC) structure
# implementation.
# • Responsible for providing the client-side JavaScript validations and usage of HTML, JavaScript, XML, JSP, CSS
# as per the requirements to enhance the Portal UI.
# • Used Spring Core for Dependency Injection.
# • Mapping of ORM objects to tables using the Hibernate as the persistence framework.
# • Involved in different service classes, used across the framework.
# • Implementation of Web Services using Axis for the integration of different systems
# • Developed applications using J2EE technologies like Spring Boot, Spring MVC on the business layer and the
# persistent layer using Hibernate as ORM tool.
# • Testing of Web Services using the Postman.
# • Used HTML, CSS, Spring MVC, JSP, and jQuery, JavaScript, Angular.js in the development and the designing the
# UI.
# • Gradient effects through the development of the CSS style sheets. Developed navigation, icons and layouts.
# • Code review and configuration build management for the application using Maven.
# • Implementation of business logic, validation Frame Work using Spring Web flow and Spring MVC.
# • Implemented Web tier of the application through the usage of Spring MVC framework.
# • Implementation of clean separation of layers through the usage of different design patterns like Factory pattern,
# Singleton and DAO pattern.
# • Serialization in the flattening of the objects.
# • Used core java concepts like Collections while developing server-side services.
# • Data storage using DB2 and used PL/SQL for queries.
# • Worked with IBM Web Sphere Application Server Developer Tools for Eclipse by using lightweight set of tools to
# assemble, develop and deploy Java EE, Web 2.0, and mobile applications.
# Anudeep
# Sr Java Programmer
# anudeepreddynallamada@gmail.com
# PROFESSIONAL SUMMARY:
# • IT professional with 8+ years of IT experience in designing and developing N-tier applications based on
# OOPS (Object Oriented Programming), Internet and Intranet, Client-Server Architecture using Java/J2EE
# and supporting technologies.
# •  Strong Experience in developing user interfaces with HTML, DHTML, XML and CSS.
# • Experienced in processing, validating, parsing and extracting data from .xml file.
# •  Worked with scripting languages like JavaScript, JQuery.
# •  Well versed in MVC (Model View Controller) architecture using Spring, JSF and implementing JSTL (JSP
# Standard Tag Library), custom tag development and tiles.
# •  Experience in JSP, Java Beans and Servlets for developing applications using MVC architecture.
# •  Good exposure in implementing web services-WSDL using SOAP protocol.
# •  Experienced in Persistence Framework like Hibernate ORM (Object Relational Mapping) in a typical n-
# tier architecture.
# • Experienced in build tools like ANT and Maven.
# • Experienced in using testing Frameworks like JUnit and JMockit.
# • Experienced in using logging tools like Intellij and Log4j.
# • Hands  on  experience  on Web/Application  servers  such  as Apache Tomcat,  JBoss, WebLogic  and Web
# Sphere.
# • Experienced in developing various UML designs like class diagrams, cases and sequence diagrams using
# Rational Rose.
# • Worked  on  different  platforms  like Windows  2003  Server, Windows  2000  Professional, Windows  XP,
# Windows […] UNIX and LINUX.
# • Experience in using UML like Rational Rose and MS Visio
# • Well versed in using version control tools like SVN, Clear Case and CVS.
# • Strong experience in using IDEs like Eclipse, NetBeans and RAD
# • Developed projects and products using Agile Methodology, SDLC (Software development life cycle), from
# initiation, planning, designing, execution, implementation and Maintenance.
# EDUCATION:
# Bachelor of Engineering in Computer Science and Engineering        JNTU, Hyderabad, India.     2009
# TECHNICAL SKILLS:
# Languages C, C++, JAVA/J2EE, PL/SQL, Shell script, UNIX commands.
# Java Technologies Core  Java,  J2EE,  JSP,  Servlet,  JDBC,  JMS,  JavaBeans,  JNDI,  Java  Mail,
# Java1.8.
# Web Technologies AngularJS, jQuery, JavaScript, HTML, DHTML, XML,
# Cascading Style Sheets (CSS), XSLT.
# XML Technologies XML Schema, DTD, JAXP, SAX and DOM parsers.
# IDEs / Tools  Eclipse, NetBeans, Red Hat Developer Studio, RAD, WSAD. / TOAD, Maven,
# XmlSpy, Ant, PL/SQ L Developer, JUnit, iReport.Operating Systems Windows 95/98/NT/2000/XP, Sun Solaris 9/10, Red Hat Linux 9.
# Design Patterns MVC,  DAO,  DTO,  Front  Controller,  Session  Façade,  Business  Delegate,
# Observer, Singleton, View Helper, Decorator, Factory Pattern, POM, object pool
# Databases and Tools Oracle8  /  9i  /10g,11g,  HSQL,  Sybase,  MySQL,  MSSQL,  MongoDB,  SQL
# Server, IBM DB2, Toad for SQL Server.
# Frameworks Struts, Spring (Dependency Injection, Spring Core, Spring MVC, Spring AOP,
# Spring  DAO,  Spring  IOC,  Spring  JDBC,  Spring  with  Hibernate),  Hibernate,
# DWR, Log4j.
# Web service specifications and  JAX-RPC, JAX-WS, JAX-RS, ESB, Axis, JWSDP, RESTful webservices.
# Implementations
# Methodologies Agile, Scrum, Test Driven Development.
# Scripting/GUI Tools HTML5, DHTML, DOJO, JSON, JavaScript, CSS3, Shell Script, Dreamweaver,
# MS FrontPage, VBScript, JSTL, JSP, NodeJS
# Additional Skills Elasticsearch, Logstash, Kibana, Graphana, Git, Bitbucket, Maven, Jenkins.
# PROFESSIONAL EXPERIENCE:
# WIND STREAM COMMUNICATION, DALLAS, TX                                                                SEP-2016 -TILL DATE
# Role: Sr Java Programmer
# Responsibilities:
# • Involved in the application development using Java platform. Model View Control (MVC) structure
# implementation.
# • Responsible for providing the client-side JavaScript validations and usage of HTML, JavaScript, XML, JSP, CSS
# as per the requirements to enhance the Portal UI.
# • Used Spring Core for Dependency Injection.
# • Mapping of ORM objects to tables using the Hibernate as the persistence framework.
# • Involved in different service classes, used across the framework.
# • Implementation of Web Services using Axis for the integration of different systems
# • Developed applications using J2EE technologies like Spring Boot, Spring MVC on the business layer and the
# persistent layer using Hibernate as ORM tool.
# • Testing of Web Services using the Postman.
# • Used HTML, CSS, Spring MVC, JSP, and jQuery, JavaScript, Angular.js in the development and the designing the
# UI.
# • Gradient effects through the development of the CSS style sheets. Developed navigation, icons and layouts.
# • Code review and configuration build management for the application using Maven.
# • Implementation of business logic, validation Frame Work using Spring Web flow and Spring MVC.
# • Implemented Web tier of the application through the usage of Spring MVC framework.
# • Implementation of clean separation of layers through the usage of different design patterns like Factory pattern,
# Singleton and DAO pattern.
# • Serialization in the flattening of the objects.
# • Used core java concepts like Collections while developing server-side services.
# • Data storage using DB2 and used PL/SQL for queries.
# • Worked with IBM Web Sphere Application Server Developer Tools for Eclipse by using lightweight set of tools to
# assemble, develop and deploy Java EE, Web 2.0, and mobile applications.  • Involved with GUI using JSP, Java Script and HTML.
# • Involved in using continuous integration tool (CI/CD) Jenkins. Created builds using Maven and pulled the project
# code from GitHub repositories.
# • Experience with Garbage collection and multithreading.
# • Experience with Concurrency, Exception Handling, File handling
# Environment: HTML, CSS, XML, SOAP, Hibernate, Java,J2EE,Java Script,MySQL DB, Spring Boot, PL/SQL,
# Log4j, JQuery, Angular JS, Eclipse, IBM Web Sphere Application server.
#
# IBM DALLAS,TEXASSEP 2015–AUG 2016
# Role: Sr Java Programmer
# Responsibilities:
# • Involved in SDLC Requirements gathering, Analysis, Design, Development and Testing of application using
# AGILE methodology (SCRUM).
# • Designed APIs and analytics using IBM Cloud. Built mobile backend services, powerful app management, and
# insights into app usage using IBM mobile first.
# • Designed DOM based interactive to reprogram selected links and adopted WCAG 2.0 standards for HTML and
# XHTML and W3C standards for CSS as well.
# • Have achieved proficiency in Unit Test, Mock, Test Driven Development etc.
# • Implemented client-side Interface using React JS. Worked on Redux.
# • Design, develop and test HTML, CSS, jQuery and React.JS that meets accessibility and web browser standards
# for car dealerships websites.
# • Installed, configured and Administered WebSphere Commerce Server 6.0 on Windows and Linux platform.
# • Involved in Stopping/Starting & Monitoring the logs for Application Server Instances.
# • Implemented Horizontal and Vertical Clustering, Performance tuning and troubleshooting of IBM WebSphere
# Application Server 6.0/6.1.
# • Installed EARs, WARs and configured application specific JVM settings, Web container parameters using the
# Admin Console and WSCP/WSadmin scripts.
# • Migrated existing applications from WebSphere V6.0 to V7.0.
# • Involved in issues like Application not responding. Application Deployment Errors, Wrong Database host name,
# Server Hung due to out of memory or thread hanging, Owner ship issue.
# • Created sites to organize client contracts and to summarize monthly financial data using React.js, Ember.js,
# D3.js and MySql.
# • Created  web  services  and  desktop  applications  to  access  and  display  data  needed  by  support  teams
# using, Ajax, JavaScript, jQuery, React.js, Angular.js, Node.js, Java, CSS and HTML.
# • Built  data  visualizations  to  monitor  file  server  load,  Web  server  speed,  Data  Processing  using  D3.js,
# jQuery and MySql.
# • Prepared exhaustive test cases to comprehensively test functionality and code.
# • Creating Java code and modifying the existing code to match with the front JavaScript files.
# • Created an on -the-fly configuration changes set up, with application saved in Node.js.
# Environment: Java, JSP, Spring (MVC and Core), JSON, Servlets, Webservices(RESTful), Web Logic Application
# server, WebSphere Application Server 6.0/6.1/7.0, Websphere Portal Server 6.0/6.1, Websphere Commerce Server
# 6.0, Apache 2.0.47, IHS 6.0/6.1
# ACADEMIC BANK KANSAS CITY,MO                                              AUG 2014 – AUG 2015
# Role: Java Programmer
# Responsibilities:
# • JSF Portal Framework at Presentation Tier and Faces Servlet acts as the Front Controller.
# Anudeep
# Sr Java Programmer
# anudeepreddynallamada@gmail.com
# PROFESSIONAL SUMMARY:
# • IT professional with 8+ years of IT experience in designing and developing N-tier applications based on
# OOPS (Object Oriented Programming), Internet and Intranet, Client-Server Architecture using Java/J2EE
# and supporting technologies.
# •  Strong Experience in developing user interfaces with HTML, DHTML, XML and CSS.
# • Experienced in processing, validating, parsing and extracting data from .xml file.
# •  Worked with scripting languages like JavaScript, JQuery.
# •  Well versed in MVC (Model View Controller) architecture using Spring, JSF and implementing JSTL (JSP
# Standard Tag Library), custom tag development and tiles.
# •  Experience in JSP, Java Beans and Servlets for developing applications using MVC architecture.
# •  Good exposure in implementing web services-WSDL using SOAP protocol.
# •  Experienced in Persistence Framework like Hibernate ORM (Object Relational Mapping) in a typical n-
# tier architecture.
# • Experienced in build tools like ANT and Maven.
# • Experienced in using testing Frameworks like JUnit and JMockit.
# • Experienced in using logging tools like Intellij and Log4j.
# • Hands  on  experience  on Web/Application  servers  such  as Apache Tomcat,  JBoss, WebLogic  and Web
# Sphere.
# • Experienced in developing various UML designs like class diagrams, cases and sequence diagrams using
# Rational Rose.
# • Worked  on  different  platforms  like Windows  2003  Server, Windows  2000  Professional, Windows  XP,
# Windows […] UNIX and LINUX.
# • Experience in using UML like Rational Rose and MS Visio
# • Well versed in using version control tools like SVN, Clear Case and CVS.
# • Strong experience in using IDEs like Eclipse, NetBeans and RAD
# • Developed projects and products using Agile Methodology, SDLC (Software development life cycle), from
# initiation, planning, designing, execution, implementation and Maintenance.
# EDUCATION:
# Bachelor of Engineering in Computer Science and Engineering        JNTU, Hyderabad, India.     2009
# TECHNICAL SKILLS:
# Languages C, C++, JAVA/J2EE, PL/SQL, Shell script, UNIX commands.
# Java Technologies Core  Java,  J2EE,  JSP,  Servlet,  JDBC,  JMS,  JavaBeans,  JNDI,  Java  Mail,
# Java1.8.
# Web Technologies AngularJS, jQuery, JavaScript, HTML, DHTML, XML,
# Cascading Style Sheets (CSS), XSLT.
# XML Technologies XML Schema, DTD, JAXP, SAX and DOM parsers.
# IDEs / Tools  Eclipse, NetBeans, Red Hat Developer Studio, RAD, WSAD. / TOAD, Maven,
# XmlSpy, Ant, PL/SQ L Developer, JUnit, iReport.Operating Systems Windows 95/98/NT/2000/XP, Sun Solaris 9/10, Red Hat Linux 9.
# Design Patterns MVC,  DAO,  DTO,  Front  Controller,  Session  Façade,  Business  Delegate,
# Observer, Singleton, View Helper, Decorator, Factory Pattern, POM, object pool
# Databases and Tools Oracle8  /  9i  /10g,11g,  HSQL,  Sybase,  MySQL,  MSSQL,  MongoDB,  SQL
# Server, IBM DB2, Toad for SQL Server.
# Frameworks Struts, Spring (Dependency Injection, Spring Core, Spring MVC, Spring AOP,
# Spring  DAO,  Spring  IOC,  Spring  JDBC,  Spring  with  Hibernate),  Hibernate,
# DWR, Log4j.
# Web service specifications and  JAX-RPC, JAX-WS, JAX-RS, ESB, Axis, JWSDP, RESTful webservices.
# Implementations
# Methodologies Agile, Scrum, Test Driven Development.
# Scripting/GUI Tools HTML5, DHTML, DOJO, JSON, JavaScript, CSS3, Shell Script, Dreamweaver,
# MS FrontPage, VBScript, JSTL, JSP, NodeJS
# Additional Skills Elasticsearch, Logstash, Kibana, Graphana, Git, Bitbucket, Maven, Jenkins.
# PROFESSIONAL EXPERIENCE:
# WIND STREAM COMMUNICATION, DALLAS, TX                                                                SEP-2016 -TILL DATE
# Role: Sr Java Programmer
# Responsibilities:
# • Involved in the application development using Java platform. Model View Control (MVC) structure
# implementation.
# • Responsible for providing the client-side JavaScript validations and usage of HTML, JavaScript, XML, JSP, CSS
# as per the requirements to enhance the Portal UI.
# • Used Spring Core for Dependency Injection.
# • Mapping of ORM objects to tables using the Hibernate as the persistence framework.
# • Involved in different service classes, used across the framework.
# • Implementation of Web Services using Axis for the integration of different systems
# • Developed applications using J2EE technologies like Spring Boot, Spring MVC on the business layer and the
# persistent layer using Hibernate as ORM tool.
# • Testing of Web Services using the Postman.
# • Used HTML, CSS, Spring MVC, JSP, and jQuery, JavaScript, Angular.js in the development and the designing the
# UI.
# • Gradient effects through the development of the CSS style sheets. Developed navigation, icons and layouts.
# • Code review and configuration build management for the application using Maven.
# • Implementation of business logic, validation Frame Work using Spring Web flow and Spring MVC.
# • Implemented Web tier of the application through the usage of Spring MVC framework.
# • Implementation of clean separation of layers through the usage of different design patterns like Factory pattern,
# Singleton and DAO pattern.
# • Serialization in the flattening of the objects.
# • Used core java concepts like Collections while developing server-side services.
# • Data storage using DB2 and used PL/SQL for queries.
# • Worked with IBM Web Sphere Application Server Developer Tools for Eclipse by using lightweight set of tools to
# assemble, develop and deploy Java EE, Web 2.0, and mobile applications.  • Involved with GUI using JSP, Java Script and HTML.
# • Involved in using continuous integration tool (CI/CD) Jenkins. Created builds using Maven and pulled the project
# code from GitHub repositories.
# • Experience with Garbage collection and multithreading.
# • Experience with Concurrency, Exception Handling, File handling
# Environment: HTML, CSS, XML, SOAP, Hibernate, Java,J2EE,Java Script,MySQL DB, Spring Boot, PL/SQL,
# Log4j, JQuery, Angular JS, Eclipse, IBM Web Sphere Application server.
#
# IBM DALLAS,TEXASSEP 2015–AUG 2016
# Role: Sr Java Programmer
# Responsibilities:
# • Involved in SDLC Requirements gathering, Analysis, Design, Development and Testing of application using
# AGILE methodology (SCRUM).
# • Designed APIs and analytics using IBM Cloud. Built mobile backend services, powerful app management, and
# insights into app usage using IBM mobile first.
# • Designed DOM based interactive to reprogram selected links and adopted WCAG 2.0 standards for HTML and
# XHTML and W3C standards for CSS as well.
# • Have achieved proficiency in Unit Test, Mock, Test Driven Development etc.
# • Implemented client-side Interface using React JS. Worked on Redux.
# • Design, develop and test HTML, CSS, jQuery and React.JS that meets accessibility and web browser standards
# for car dealerships websites.
# • Installed, configured and Administered WebSphere Commerce Server 6.0 on Windows and Linux platform.
# • Involved in Stopping/Starting & Monitoring the logs for Application Server Instances.
# • Implemented Horizontal and Vertical Clustering, Performance tuning and troubleshooting of IBM WebSphere
# Application Server 6.0/6.1.
# • Installed EARs, WARs and configured application specific JVM settings, Web container parameters using the
# Admin Console and WSCP/WSadmin scripts.
# • Migrated existing applications from WebSphere V6.0 to V7.0.
# • Involved in issues like Application not responding. Application Deployment Errors, Wrong Database host name,
# Server Hung due to out of memory or thread hanging, Owner ship issue.
# • Created sites to organize client contracts and to summarize monthly financial data using React.js, Ember.js,
# D3.js and MySql.
# • Created  web  services  and  desktop  applications  to  access  and  display  data  needed  by  support  teams
# using, Ajax, JavaScript, jQuery, React.js, Angular.js, Node.js, Java, CSS and HTML.
# • Built  data  visualizations  to  monitor  file  server  load,  Web  server  speed,  Data  Processing  using  D3.js,
# jQuery and MySql.
# • Prepared exhaustive test cases to comprehensively test functionality and code.
# • Creating Java code and modifying the existing code to match with the front JavaScript files.
# • Created an on -the-fly configuration changes set up, with application saved in Node.js.
# Environment: Java, JSP, Spring (MVC and Core), JSON, Servlets, Webservices(RESTful), Web Logic Application
# server, WebSphere Application Server 6.0/6.1/7.0, Websphere Portal Server 6.0/6.1, Websphere Commerce Server
# 6.0, Apache 2.0.47, IHS 6.0/6.1
# ACADEMIC BANK KANSAS CITY,MO                                              AUG 2014 – AUG 2015
# Role: Java Programmer
# Responsibilities:
# • JSF Portal Framework at Presentation Tier and Faces Servlet acts as the Front Controller. • Actively participated and mentoring in requirements gathering, analysis, design, and development and testing
# phases.
# • Worked one-on-one with client to develop layout, color scheme for his website and implemented it into a final
# interface design with the HTML5/CSS3 & JavaScript using Dreamweaver.
# • Developed CSS3 style sheets to give gradient effects. Developed page layouts, navigation and icons. Applied
# industry best practices and standards when project requirements were lagging.
# • Created Images, Logos and Icons that are used across the web pages using Adobe Flash and Photoshop.
# • Designed Frontend with in object oriented JavaScript framework like Angular.JS, Node.js and Ext.JS.
# • Used EXTJS for building rich internet applications, backbone JS & Require JS to optimize in-browser use and
# to load the module and to improve the Speed.
# • Working  on  all  the  latest  technologies  like  HTML5,  CSS3,  etc.  Tackled  various  issues  related  browser
# compatibility to accommodate these advanced and fast technologies
# • Troubleshoot Admin Server start-up issues, Java code defects after deployment, and class path issues by
# checking the JVM logs, plug-in logs and the Webserver logs
# • Worked closely with developers to define and configured application Servers, Virtual Hosts, Web Applications,
# Web resources, Servlets, JDBC drivers and Servlet Engines-as well as deployment of EJBs across multiple
# instances of WebSphere.
# • Maintained security, tuning and clustering on Web Sphere Application Server using IBM Web seal Tivoli
# Access Manager.
# • Monitored the logs for Application Server Instances.
# • Updated application code from JDK 1.3 to 1.4 using WSAD, RAD and redeployed in a clustered environment.
# • Design and develop solutions using C, C++, Multi-Threaded, Shell Scripting.
# • Debugged the application using Firebug to traverse the documents and manipulated the Nodes using DOM and
# DOM Functions using Firefox and IE Developer Tool bar for IE.
# • Used JavaScript and XML to update a portion of a web page thus reducing bandwidth usage and load time and
# add modal dialog in web pages to get user input and requests.
# • Used Soap over Http and Soap over JMS for communication between components.
# • Worked  with  the  team  of  architects  and  back-end  Developers  to  gather  requirements  and  enhance  the
# application functionality and add new features.
# Environment:HTML5, CSS3, JavaScript, jQuery, DOM, DML, DHTML, EXT JS, Angular.js, Node.js, Backbone.js,
# Require.js, Adobe  Flash,  Photoshop,  Dreamweaver,  XML, Apache,  SOAP,  Internet  Explorer,  Firefox,  Chrome,
# Oracle, Windows, C, C++, Agile Methodology.
# VALUE LABS, HYDERABAD, INDIA                                                                                      JUNE 2012 –
# JULY2014
# Role: Java Programmer
# Responsibilities:
# • Utilized  the  base  UML  methodologies  and  Use  cases  modeled  by  architects  to  develop  the  front-end
# interface. The class, sequence and state diagrams were developed using Microsoft Visio.
# • Created User Interface (UI) to gather data and communicate with Business Layer by using Swing, HTML,
# JSP, JSP Tags Lib, JSTL and Java Script.
# • Utilized AJAX to increase web page’s interactivity, speed and functionality.
# • Implemented MVC architecture using Spring 2.5 MVC framework and enhanced the design using Stateless
# Session Beans for the Middle Tier Development
# • Utilized WSDL and SOAP to implement Web Services to optimize performance by using remote model
# applications.
# • Used JSF framework for implementing the Web tier of the application.
# Anudeep
# Sr Java Programmer
# anudeepreddynallamada@gmail.com
# PROFESSIONAL SUMMARY:
# • IT professional with 8+ years of IT experience in designing and developing N-tier applications based on
# OOPS (Object Oriented Programming), Internet and Intranet, Client-Server Architecture using Java/J2EE
# and supporting technologies.
# •  Strong Experience in developing user interfaces with HTML, DHTML, XML and CSS.
# • Experienced in processing, validating, parsing and extracting data from .xml file.
# •  Worked with scripting languages like JavaScript, JQuery.
# •  Well versed in MVC (Model View Controller) architecture using Spring, JSF and implementing JSTL (JSP
# Standard Tag Library), custom tag development and tiles.
# •  Experience in JSP, Java Beans and Servlets for developing applications using MVC architecture.
# •  Good exposure in implementing web services-WSDL using SOAP protocol.
# •  Experienced in Persistence Framework like Hibernate ORM (Object Relational Mapping) in a typical n-
# tier architecture.
# • Experienced in build tools like ANT and Maven.
# • Experienced in using testing Frameworks like JUnit and JMockit.
# • Experienced in using logging tools like Intellij and Log4j.
# • Hands  on  experience  on Web/Application  servers  such  as Apache Tomcat,  JBoss, WebLogic  and Web
# Sphere.
# • Experienced in developing various UML designs like class diagrams, cases and sequence diagrams using
# Rational Rose.
# • Worked  on  different  platforms  like Windows  2003  Server, Windows  2000  Professional, Windows  XP,
# Windows […] UNIX and LINUX.
# • Experience in using UML like Rational Rose and MS Visio
# • Well versed in using version control tools like SVN, Clear Case and CVS.
# • Strong experience in using IDEs like Eclipse, NetBeans and RAD
# • Developed projects and products using Agile Methodology, SDLC (Software development life cycle), from
# initiation, planning, designing, execution, implementation and Maintenance.
# EDUCATION:
# Bachelor of Engineering in Computer Science and Engineering        JNTU, Hyderabad, India.     2009
# TECHNICAL SKILLS:
# Languages C, C++, JAVA/J2EE, PL/SQL, Shell script, UNIX commands.
# Java Technologies Core  Java,  J2EE,  JSP,  Servlet,  JDBC,  JMS,  JavaBeans,  JNDI,  Java  Mail,
# Java1.8.
# Web Technologies AngularJS, jQuery, JavaScript, HTML, DHTML, XML,
# Cascading Style Sheets (CSS), XSLT.
# XML Technologies XML Schema, DTD, JAXP, SAX and DOM parsers.
# IDEs / Tools  Eclipse, NetBeans, Red Hat Developer Studio, RAD, WSAD. / TOAD, Maven,
# XmlSpy, Ant, PL/SQ L Developer, JUnit, iReport.Operating Systems Windows 95/98/NT/2000/XP, Sun Solaris 9/10, Red Hat Linux 9.
# Design Patterns MVC,  DAO,  DTO,  Front  Controller,  Session  Façade,  Business  Delegate,
# Observer, Singleton, View Helper, Decorator, Factory Pattern, POM, object pool
# Databases and Tools Oracle8  /  9i  /10g,11g,  HSQL,  Sybase,  MySQL,  MSSQL,  MongoDB,  SQL
# Server, IBM DB2, Toad for SQL Server.
# Frameworks Struts, Spring (Dependency Injection, Spring Core, Spring MVC, Spring AOP,
# Spring  DAO,  Spring  IOC,  Spring  JDBC,  Spring  with  Hibernate),  Hibernate,
# DWR, Log4j.
# Web service specifications and  JAX-RPC, JAX-WS, JAX-RS, ESB, Axis, JWSDP, RESTful webservices.
# Implementations
# Methodologies Agile, Scrum, Test Driven Development.
# Scripting/GUI Tools HTML5, DHTML, DOJO, JSON, JavaScript, CSS3, Shell Script, Dreamweaver,
# MS FrontPage, VBScript, JSTL, JSP, NodeJS
# Additional Skills Elasticsearch, Logstash, Kibana, Graphana, Git, Bitbucket, Maven, Jenkins.
# PROFESSIONAL EXPERIENCE:
# WIND STREAM COMMUNICATION, DALLAS, TX                                                                SEP-2016 -TILL DATE
# Role: Sr Java Programmer
# Responsibilities:
# • Involved in the application development using Java platform. Model View Control (MVC) structure
# implementation.
# • Responsible for providing the client-side JavaScript validations and usage of HTML, JavaScript, XML, JSP, CSS
# as per the requirements to enhance the Portal UI.
# • Used Spring Core for Dependency Injection.
# • Mapping of ORM objects to tables using the Hibernate as the persistence framework.
# • Involved in different service classes, used across the framework.
# • Implementation of Web Services using Axis for the integration of different systems
# • Developed applications using J2EE technologies like Spring Boot, Spring MVC on the business layer and the
# persistent layer using Hibernate as ORM tool.
# • Testing of Web Services using the Postman.
# • Used HTML, CSS, Spring MVC, JSP, and jQuery, JavaScript, Angular.js in the development and the designing the
# UI.
# • Gradient effects through the development of the CSS style sheets. Developed navigation, icons and layouts.
# • Code review and configuration build management for the application using Maven.
# • Implementation of business logic, validation Frame Work using Spring Web flow and Spring MVC.
# • Implemented Web tier of the application through the usage of Spring MVC framework.
# • Implementation of clean separation of layers through the usage of different design patterns like Factory pattern,
# Singleton and DAO pattern.
# • Serialization in the flattening of the objects.
# • Used core java concepts like Collections while developing server-side services.
# • Data storage using DB2 and used PL/SQL for queries.
# • Worked with IBM Web Sphere Application Server Developer Tools for Eclipse by using lightweight set of tools to
# assemble, develop and deploy Java EE, Web 2.0, and mobile applications.  • Involved with GUI using JSP, Java Script and HTML.
# • Involved in using continuous integration tool (CI/CD) Jenkins. Created builds using Maven and pulled the project
# code from GitHub repositories.
# • Experience with Garbage collection and multithreading.
# • Experience with Concurrency, Exception Handling, File handling
# Environment: HTML, CSS, XML, SOAP, Hibernate, Java,J2EE,Java Script,MySQL DB, Spring Boot, PL/SQL,
# Log4j, JQuery, Angular JS, Eclipse, IBM Web Sphere Application server.
#
# IBM DALLAS,TEXASSEP 2015–AUG 2016
# Role: Sr Java Programmer
# Responsibilities:
# • Involved in SDLC Requirements gathering, Analysis, Design, Development and Testing of application using
# AGILE methodology (SCRUM).
# • Designed APIs and analytics using IBM Cloud. Built mobile backend services, powerful app management, and
# insights into app usage using IBM mobile first.
# • Designed DOM based interactive to reprogram selected links and adopted WCAG 2.0 standards for HTML and
# XHTML and W3C standards for CSS as well.
# • Have achieved proficiency in Unit Test, Mock, Test Driven Development etc.
# • Implemented client-side Interface using React JS. Worked on Redux.
# • Design, develop and test HTML, CSS, jQuery and React.JS that meets accessibility and web browser standards
# for car dealerships websites.
# • Installed, configured and Administered WebSphere Commerce Server 6.0 on Windows and Linux platform.
# • Involved in Stopping/Starting & Monitoring the logs for Application Server Instances.
# • Implemented Horizontal and Vertical Clustering, Performance tuning and troubleshooting of IBM WebSphere
# Application Server 6.0/6.1.
# • Installed EARs, WARs and configured application specific JVM settings, Web container parameters using the
# Admin Console and WSCP/WSadmin scripts.
# • Migrated existing applications from WebSphere V6.0 to V7.0.
# • Involved in issues like Application not responding. Application Deployment Errors, Wrong Database host name,
# Server Hung due to out of memory or thread hanging, Owner ship issue.
# • Created sites to organize client contracts and to summarize monthly financial data using React.js, Ember.js,
# D3.js and MySql.
# • Created  web  services  and  desktop  applications  to  access  and  display  data  needed  by  support  teams
# using, Ajax, JavaScript, jQuery, React.js, Angular.js, Node.js, Java, CSS and HTML.
# • Built  data  visualizations  to  monitor  file  server  load,  Web  server  speed,  Data  Processing  using  D3.js,
# jQuery and MySql.
# • Prepared exhaustive test cases to comprehensively test functionality and code.
# • Creating Java code and modifying the existing code to match with the front JavaScript files.
# • Created an on -the-fly configuration changes set up, with application saved in Node.js.
# Environment: Java, JSP, Spring (MVC and Core), JSON, Servlets, Webservices(RESTful), Web Logic Application
# server, WebSphere Application Server 6.0/6.1/7.0, Websphere Portal Server 6.0/6.1, Websphere Commerce Server
# 6.0, Apache 2.0.47, IHS 6.0/6.1
# ACADEMIC BANK KANSAS CITY,MO                                              AUG 2014 – AUG 2015
# Role: Java Programmer
# Responsibilities:
# • JSF Portal Framework at Presentation Tier and Faces Servlet acts as the Front Controller. • Actively participated and mentoring in requirements gathering, analysis, design, and development and testing
# phases.
# • Worked one-on-one with client to develop layout, color scheme for his website and implemented it into a final
# interface design with the HTML5/CSS3 & JavaScript using Dreamweaver.
# • Developed CSS3 style sheets to give gradient effects. Developed page layouts, navigation and icons. Applied
# industry best practices and standards when project requirements were lagging.
# • Created Images, Logos and Icons that are used across the web pages using Adobe Flash and Photoshop.
# • Designed Frontend with in object oriented JavaScript framework like Angular.JS, Node.js and Ext.JS.
# • Used EXTJS for building rich internet applications, backbone JS & Require JS to optimize in-browser use and
# to load the module and to improve the Speed.
# • Working  on  all  the  latest  technologies  like  HTML5,  CSS3,  etc.  Tackled  various  issues  related  browser
# compatibility to accommodate these advanced and fast technologies
# • Troubleshoot Admin Server start-up issues, Java code defects after deployment, and class path issues by
# checking the JVM logs, plug-in logs and the Webserver logs
# • Worked closely with developers to define and configured application Servers, Virtual Hosts, Web Applications,
# Web resources, Servlets, JDBC drivers and Servlet Engines-as well as deployment of EJBs across multiple
# instances of WebSphere.
# • Maintained security, tuning and clustering on Web Sphere Application Server using IBM Web seal Tivoli
# Access Manager.
# • Monitored the logs for Application Server Instances.
# • Updated application code from JDK 1.3 to 1.4 using WSAD, RAD and redeployed in a clustered environment.
# • Design and develop solutions using C, C++, Multi-Threaded, Shell Scripting.
# • Debugged the application using Firebug to traverse the documents and manipulated the Nodes using DOM and
# DOM Functions using Firefox and IE Developer Tool bar for IE.
# • Used JavaScript and XML to update a portion of a web page thus reducing bandwidth usage and load time and
# add modal dialog in web pages to get user input and requests.
# • Used Soap over Http and Soap over JMS for communication between components.
# • Worked  with  the  team  of  architects  and  back-end  Developers  to  gather  requirements  and  enhance  the
# application functionality and add new features.
# Environment:HTML5, CSS3, JavaScript, jQuery, DOM, DML, DHTML, EXT JS, Angular.js, Node.js, Backbone.js,
# Require.js, Adobe  Flash,  Photoshop,  Dreamweaver,  XML, Apache,  SOAP,  Internet  Explorer,  Firefox,  Chrome,
# Oracle, Windows, C, C++, Agile Methodology.
# VALUE LABS, HYDERABAD, INDIA                                                                                      JUNE 2012 –
# JULY2014
# Role: Java Programmer
# Responsibilities:
# • Utilized  the  base  UML  methodologies  and  Use  cases  modeled  by  architects  to  develop  the  front-end
# interface. The class, sequence and state diagrams were developed using Microsoft Visio.
# • Created User Interface (UI) to gather data and communicate with Business Layer by using Swing, HTML,
# JSP, JSP Tags Lib, JSTL and Java Script.
# • Utilized AJAX to increase web page’s interactivity, speed and functionality.
# • Implemented MVC architecture using Spring 2.5 MVC framework and enhanced the design using Stateless
# Session Beans for the Middle Tier Development
# • Utilized WSDL and SOAP to implement Web Services to optimize performance by using remote model
# applications.
# • Used JSF framework for implementing the Web tier of the application. • Designed and implemented complex multi-application flow through integration implemented using XML,
# XSL and JMS configurations.
# • Implemented Object-relation mapping in the persistence layer using hibernate frame work in conjunction
# with Spring Aspect Oriented Programming (AOP) functionality.
# • Used CVS as a documentation repository and version controlling tool.
# • Used ANT scripts for build creation and to push onto various environments.
# • Used JUnit 4.2 for extensive functional and unit testing code.
# • Used Log4j for logging and debugging.
# Environment: Core Java, JDK 1.5, J2EE 5, HTML, CSS 2.1, JSP 2.1, JSF 1.2, JNDI, AJAX, Swing, Spring 2.5,
# Hibernate 3.0, JMS 1.1, SOAP UI, WSDL, UML, XML, XSLT, Windows XP, ANT, UNIX, Log4J, MVC Design
# Pattern, DAO, Eclipse IDE.
# AJR INFOTECH, HYDERABAD, INDIA                                                                              AUG-2009 – JUNE-2012
# Role: Java Developer
# Responsibili1es:
# • Worked on writing Java code for extracting backend data from the main frames.
# • Instantiated business objects with IOC pattern using spring framework and for Dependency Injection.
# • Implemented Object-relation mapping in the persistence layer using Hibernate frame work in conjunction
# with spring functionality.
# • Agile process is used for tracking and developing the application.
# • Development and Integration of the Application using Eclipse IDE and used StarTeam as Version Control
# Tool.
# • Implemented the integration with the back-end system with web services using Axis and SOAP
# • Utilized JUnit test cases for all the developed modules.
# • Extensive experience in different IDEs like RAD, Eclipse, NetBeans.
# Environment: Java, J2EE, Spring Framework, HTML, JavaScript, Hibernate, Eclipse IDE, Star Team, Axis, SOAP,
# JUnit, RAD, Eclipse, NetBeans.
# .

# %% [markdown]
# # Import CV and scraped data

# %%
# Import CV

f=open('test.txt','r', errors = 'ignore')
text=f.read()

# Locations
f1=open('india_districts.txt','r', errors = 'ignore')
text1=f1.read()
locations = word_tokenize(text1.replace("\n", " "))

# Additional stopwords
f2=open('stopwords.txt','r', errors = 'ignore')
text2=f2.read()
stopwords_additional = word_tokenize(text2.replace("\n", " "))

# %%
def nlp(x):
    word_sent = word_tokenize(x.lower().replace("\n",""))
    _stopwords = set(stopwords.words('english') + list(punctuation)+list("●")+list('–')+list('’')+locations+stopwords_additional)
    word_sent=[word for word in word_sent if word not in _stopwords]
    lemmatizer = WordNetLemmatizer()
    NLP_Processed_CV = [lemmatizer.lemmatize(word) for word in word_tokenize(" ".join(word_sent))]
    # return " ".join(NLP_Processed_CV)
    return NLP_Processed_CV

# %%
 nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
NLP_Processed_CV = nlp(text)
# NLP_Processed_CV=' '.join(NLP_Processed_CV)
NLP_Processed_CV
# Out:
# ['anudeep',
#  'sr',
#  'java',
#  'programmer',
#  'anudeepreddynallamada',
#  'gmail.com',
#  'professional',
#  'summary',
#  '•',
#  'professional',
#  '8+',
#  'experience',
#  'designing',
#  'developing',
#  'n-tier',
#  'application',
#  'based',
#  'oops',
#  'object',
#  'oriented',
#  'programming',
#  'internet',
#  'intranet',
#  'client-server',
#  'architecture',
#  'using',
#  'java/j2ee',
#  'supporting',
#  'technology',
#  '•',
#  'strong',
#  'experience',
#  'developing',
#  'user',
#  'interface',
#  'html',
#  'dhtml',
#  'xml',
#  'cs',
#  '•',
#  'experienced',
#  'processing',
#  'validating',
#  'parsing',
#  'extracting',
#  'data',
#  '.xml',
#  'file',
#  '•',
#  'scripting',
#  'language',
#  'javascript',
#  'jquery',
#  '•',
#  'versed',
#  'mvc',
#  'model',
#  'view',
#  'controller',
#  'architecture',
#  'using',
#  'spring',
#  'jsf',
#  'implementing',
#  'jstl',
#  'jsp',
#  'standard',
#  'tag',
#  'library',
#  'custom',
#  'tag',
#  'development',
#  'tile',
#  '•',
#  'experience',
#  'jsp',
#  'java',
#  'bean',
#  'servlets',
#  'developing',
#  'application',
#  'using',
#  'mvc',
#  'architecture',
#  '•',
#  'exposure',
#  'implementing',
#  'web',
#  'services-wsdl',
#  'using',
#  'soap',
#  'protocol',
#  '•',
#  'experienced',
#  'persistence',
#  'framework',
#  'hibernate',
#  'orm',
#  'object',
#  'relational',
#  'mapping',
#  'typical',
#  'n-tier',
#  'architecture',
#  '•',
#  'experienced',
#  'build',
#  'tool',
#  'ant',
#  'maven',
#  '•',
#  'experienced',
#  'using',
#  'testing',
#  'framework',
#  'junit',
#  'jmockit',
#  '•',
#  'experienced',
#  'using',
#  'logging',
#  'tool',
#  'intellij',
#  'log4j',
#  '•',
#  'hand',
#  'experience',
#  'web/application',
#  'server',
#  'apache',
#  'tomcat',
#  'jboss',
#  'weblogic',
#  'web',
#  'sphere',
#  '•',
#  'experienced',
#  'developing',
#  'various',
#  'uml',
#  'design',
#  'class',
#  'diagram',
#  'sequence',
#  'diagram',
#  'using',
#  'rational',
#  'rose',
#  '•',
#  'platform',
#  'window',
#  '2003',
#  'server',
#  'window',
#  '2000',
#  'professional',
#  'window',
#  'xp',
#  'window',
#  '…',
#  'unix',
#  'linux',
#  '•',
#  'experience',
#  'using',
#  'uml',
#  'rational',
#  'rose',
#  'm',
#  'visio',
#  '•',
#  'versed',
#  'using',
#  'version',
#  'control',
#  'tool',
#  'svn',
#  'cv',
#  '•',
#  'strong',
#  'experience',
#  'using',
#  'ides',
#  'eclipse',
#  'netbeans',
#  'rad',
#  '•',
#  'developed',
#  'project',
#  'product',
#  'using',
#  'agile',
#  'methodology',
#  'sdlc',
#  'software',
#  'development',
#  'life',
#  'cycle',
#  'initiation',
#  'planning',
#  'designing',
#  'execution',
#  'implementation',
#  'maintenance',
#  'education',
#  'bachelor',
#  'engineering',
#  'computer',
#  'science',
#  'engineering',
#  'jntu',
#  'hyderabad',
#  'india',
#  '2009',
#  'technical',
#  'skill',
#  'language',
#  'c++',
#  'java/j2ee',
#  'pl/sql',
#  'shell',
#  'script',
#  'unix',
#  'commands.java',
#  'technology',
#  'core',
#  'java',
#  'j2ee',
#  'jsp',
#  'servlet',
#  'jdbc',
#  'jms',
#  'javabeans',
#  'jndi',
#  'java',
#  'mail',
#  'java1.8.web',
#  'technology',
#  'angularjs',
#  'jquery',
#  'javascript',
#  'html',
#  'dhtml',
#  'xml',
#  'cascading',
#  'style',
#  'sheet',
#  'cs',
#  'xslt.xml',
#  'technology',
#  'xml',
#  'schema',
#  'dtd',
#  'jaxp',
#  'sax',
#  'dom',
#  'parsers.ides',
#  'tool',
#  'eclipse',
#  'netbeans',
#  'red',
#  'hat',
#  'developer',
#  'studio',
#  'rad',
#  'wsad',
#  'toad',
#  'maven',
#  'xmlspy',
#  'ant',
#  'pl/sq',
#  'developer',
#  'junit',
#  'ireport.anudeep',
#  'sr',
#  'java',
#  'programmer',
#  'anudeepreddynallamada',
#  'gmail.com',
#  'professional',
#  'summary',
#  '•',
#  'professional',
#  '8+',
#  'experience',
#  'designing',
#  'developing',
#  'n-tier',
#  'application',
#  'based',
#  'oops',
#  'object',
#  'oriented',
#  'programming',
#  'internet',
#  'intranet',
#  'client-server',
#  'architecture',
#  'using',
#  'java/j2ee',
#  'supporting',
#  'technology',
#  '•',
#  'strong',
#  'experience',
#  'developing',
#  'user',
#  'interface',
#  'html',
#  'dhtml',
#  'xml',
#  'cs',
#  '•',
#  'experienced',
#  'processing',
#  'validating',
#  'parsing',
#  'extracting',
#  'data',
#  '.xml',
#  'file',
#  '•',
#  'scripting',
#  'language',
#  'javascript',
#  'jquery',
#  '•',
#  'versed',
#  'mvc',
#  'model',
#  'view',
#  'controller',
#  'architecture',
#  'using',
#  'spring',
#  'jsf',
#  'implementing',
#  'jstl',
#  'jsp',
#  'standard',
#  'tag',
#  'library',
#  'custom',
#  'tag',
#  'development',
#  'tile',
#  '•',
#  'experience',
#  'jsp',
#  'java',
#  'bean',
#  'servlets',
#  'developing',
#  'application',
#  'using',
#  'mvc',
#  'architecture',
#  '•',
#  'exposure',
#  'implementing',
#  'web',
#  'services-wsdl',
#  'using',
#  'soap',
#  'protocol',
#  '•',
#  'experienced',
#  'persistence',
#  'framework',
#  'hibernate',
#  'orm',
#  'object',
#  'relational',
#  'mapping',
#  'typical',
#  'n-tier',
#  'architecture',
#  '•',
#  'experienced',
#  'build',
#  'tool',
#  'ant',
#  'maven',
#  '•',
#  'experienced',
#  'using',
#  'testing',
#  'framework',
#  'junit',
#  'jmockit',
#  '•',
#  'experienced',
#  'using',
#  'logging',
#  'tool',
#  'intellij',
#  'log4j',
#  '•',
#  'hand',
#  'experience',
#  'web/application',
#  'server',
#  'apache',
#  'tomcat',
#  'jboss',
#  'weblogic',
#  'web',
#  'sphere',
#  '•',
#  'experienced',
#  'developing',
#  'various',
#  'uml',
#  'design',
#  'class',
#  'diagram',
#  'sequence',
#  'diagram',
#  'using',
#  'rational',
#  'rose',
#  '•',
#  'platform',
#  'window',
#  '2003',
#  'server',
#  'window',
#  '2000',
#  'professional',
#  'window',
#  'xp',
#  'window',
#  '…',
#  'unix',
#  'linux',
#  '•',
#  'experience',
#  'using',
#  'uml',
#  'rational',
#  'rose',
#  'm',
#  'visio',
#  '•',
#  'versed',
#  'using',
#  'version',
#  'control',
#  'tool',
#  'svn',
#  'cv',
#  '•',
#  'strong',
#  'experience',
#  'using',
#  'ides',
#  'eclipse',
#  'netbeans',
#  'rad',
#  '•',
#  'developed',
#  'project',
#  'product',
#  'using',
#  'agile',
#  'methodology',
#  'sdlc',
#  'software',
#  'development',
#  'life',
#  'cycle',
#  'initiation',
#  'planning',
#  'designing',
#  'execution',
#  'implementation',
#  'maintenance',
#  'education',
#  'bachelor',
#  'engineering',
#  'computer',
#  'science',
#  'engineering',
#  'jntu',
#  'hyderabad',
#  'india',
#  '2009',
#  'technical',
#  'skill',
#  'language',
#  'c++',
#  'java/j2ee',
#  'pl/sql',
#  'shell',
#  'script',
#  'unix',
#  'commands.java',
#  'technology',
#  'core',
#  'java',
#  'j2ee',
#  'jsp',
#  'servlet',
#  'jdbc',
#  'jms',
#  'javabeans',
#  'jndi',
#  'java',
#  'mail',
#  'java1.8.web',
#  'technology',
#  'angularjs',
#  'jquery',
#  'javascript',
#  'html',
#  'dhtml',
#  'xml',
#  'cascading',
#  'style',
#  'sheet',
#  'cs',
#  'xslt.xml',
#  'technology',
#  'xml',
#  'schema',
#  'dtd',
#  'jaxp',
#  'sax',
#  'dom',
#  'parsers.ides',
#  'tool',
#  'eclipse',
#  'netbeans',
#  'red',
#  'hat',
#  'developer',
#  'studio',
#  'rad',
#  'wsad',
#  'toad',
#  'maven',
#  'xmlspy',
#  'ant',
#  'pl/sq',
#  'developer',
#  'junit',
#  'ireport.operating',
#  'system',
#  'window',
#  '95/98/nt/2000/xp',
#  'sun',
#  'solaris',
#  '9/10',
#  'red',
#  'hat',
#  'linux',
#  '9.design',
#  'pattern',
#  'mvc',
#  'dao',
#  'dto',
#  'front',
#  'controller',
#  'session',
#  'façade',
#  'business',
#  'delegate',
#  'observer',
#  'singleton',
#  'view',
#  'helper',
#  'decorator',
#  'factory',
#  'pattern',
#  'pom',
#  'object',
#  'pooldatabases',
#  'tool',
#  'oracle8',
#  '9i',
#  '/10g,11g',
#  'hsql',
#  'sybase',
#  'mysql',
#  'mssql',
#  'mongodb',
#  'sql',
#  'server',
#  'ibm',
#  'db2',
#  'toad',
#  'sql',
#  'server.frameworks',
#  'strut',
#  'spring',
#  'dependency',
#  'injection',
#  'spring',
#  'core',
#  'spring',
#  'mvc',
#  'spring',
#  'aop',
#  'spring',
#  'dao',
#  'spring',
#  'ioc',
#  'spring',
#  'jdbc',
#  'spring',
#  'hibernate',
#  'hibernate',
#  'dwr',
#  'log4j.web',
#  'service',
#  'specification',
#  'jax-rpc',
#  'jax-ws',
#  'jax-rs',
#  'esb',
#  'axis',
#  'jwsdp',
#  'restful',
#  'webservices.implementationsmethodologies',
#  'agile',
#  'scrum',
#  'test',
#  'driven',
#  'development.scripting/gui',
#  'tool',
#  'html5',
#  'dhtml',
#  'dojo',
#  'json',
#  'javascript',
#  'css3',
#  'shell',
#  'script',
#  'dreamweaver',
#  'm',
#  'frontpage',
#  'vbscript',
#  'jstl',
#  'jsp',
#  'nodejsadditional',
#  'skill',
#  'elasticsearch',
#  'logstash',
#  'kibana',
#  'graphana',
#  'git',
#  'bitbucket',
#  'maven',
#  'jenkins.professional',
#  'experience',
#  'wind',
#  'stream',
#  'communication',
#  'dallas',
#  'tx',
#  'sep-2016',
#  '-till',
#  'date',
#  'role',
#  'sr',
#  'java',
#  'programmer',
#  'responsibility',
#  '•',
#  'involved',
#  'application',
#  'development',
#  'using',
#  'java',
#  'platform',
#  'model',
#  'view',
#  'control',
#  'mvc',
#  'structure',
#  'implementation',
#  '•',
#  'responsible',
#  'providing',
#  'client-side',
#  'javascript',
#  'validation',
#  'usage',
#  'html',
#  'javascript',
#  'xml',
#  'jsp',
#  'cs',
#  'requirement',
#  'enhance',
#  'portal',
#  'ui',
#  '•',
#  'spring',
#  'core',
#  'dependency',
#  'injection',
#  '•',
#  'mapping',
#  'orm',
#  'object',
#  'table',
#  'using',
#  'hibernate',
#  'persistence',
#  'framework',
#  '•',
#  'involved',
#  'service',
#  'class',
#  'framework',
#  '•',
#  'implementation',
#  'web',
#  'service',
#  'using',
#  'axis',
#  'integration',
#  'system',
#  '•',
#  'developed',
#  'application',
#  'using',
#  'j2ee',
#  'technology',
#  'spring',
#  'boot',
#  'spring',
#  'mvc',
#  'business',
#  'layer',
#  'persistent',
#  'layer',
#  'using',
#  'hibernate',
#  'orm',
#  'tool',
#  '•',
#  'testing',
#  'web',
#  'service',
#  'using',
#  'postman',
#  '•',
#  'html',
#  'cs',
#  'spring',
#  'mvc',
#  'jsp',
#  'jquery',
#  'javascript',
#  'angular.js',
#  'development',
#  'designing',
#  'ui',
#  '•',
#  'gradient',
#  'effect',
#  'development',
#  'cs',
#  'style',
#  'sheet',
#  'developed',
#  'navigation',
#  'icon',
#  'layout',
#  '•',
#  'code',
#  'review',
#  'configuration',
#  'build',
#  'management',
#  'application',
#  'using',
#  'maven',
#  '•',
#  'implementation',
#  'business',
#  'logic',
#  'validation',
#  'frame',
#  'using',
#  'spring',
#  'web',
#  'flow',
#  'spring',
#  'mvc',
#  '•',
#  'implemented',
#  'web',
#  'tier',
#  'application',
#  'usage',
#  'spring',
#  'mvc',
#  'framework',
#  '•',
#  'implementation',
#  'clean',
#  'separation',
#  'layer',
#  'usage',
#  'design',
#  'pattern',
#  'factory',
#  'pattern',
#  'singleton',
#  'dao',
#  'pattern',
#  '•',
#  'serialization',
#  'flattening',
#  'object',
#  '•',
#  'core',
#  'java',
#  'concept',
#  'collection',
#  'developing',
#  'server-side',
#  'service',
#  '•',
#  'data',
#  'storage',
#  'using',
#  'db2',
#  'pl/sql',
#  'query',
#  '•',
#  'ibm',
#  'web',
#  'sphere',
#  'application',
#  'server',
#  'developer',
#  'tool',
#  'eclipse',
#  'using',
#  'lightweight',
#  'set',
#  'tool',
#  'assemble',
#  'develop',
#  'deploy',
#  'java',
#  'ee',
#  'web',
#  '2.0',
#  'mobile',
#  'application',
#  'anudeep',
#  'sr',
#  'java',
#  'programmer',
#  'anudeepreddynallamada',
#  'gmail.com',
#  'professional',
#  'summary',
#  '•',
#  'professional',
#  '8+',
#  'experience',
#  'designing',
#  'developing',
#  'n-tier',
#  'application',
#  'based',
#  'oops',
#  'object',
#  'oriented',
#  'programming',
#  'internet',
#  'intranet',
#  'client-server',
#  'architecture',
#  'using',
#  'java/j2ee',
#  'supporting',
#  'technology',
#  '•',
#  'strong',
#  'experience',
#  'developing',
#  'user',
#  'interface',
#  'html',
#  'dhtml',
#  'xml',
#  'cs',
#  '•',
#  'experienced',
#  'processing',
#  'validating',
#  'parsing',
#  'extracting',
#  'data',
#  '.xml',
#  'file',
#  '•',
#  'scripting',
#  'language',
#  'javascript',
#  'jquery',
#  '•',
#  'versed',
#  'mvc',
#  'model',
#  'view',
#  'controller',
#  'architecture',
#  'using',
#  'spring',
#  'jsf',
#  'implementing',
#  'jstl',
#  'jsp',
#  'standard',
#  'tag',
#  'library',
#  'custom',
#  'tag',
#  'development',
#  'tile',
#  '•',
#  'experience',
#  'jsp',
#  'java',
#  'bean',
#  'servlets',
#  'developing',
#  'application',
#  'using',
#  'mvc',
#  'architecture',
#  '•',
#  'exposure',
#  'implementing',
#  'web',
#  'services-wsdl',
#  'using',
#  'soap',
#  'protocol',
#  '•',
#  'experienced',
#  'persistence',
#  'framework',
#  'hibernate',
#  'orm',
#  'object',
#  'relational',
#  'mapping',
#  'typical',
#  'n-tier',
#  'architecture',
#  '•',
#  'experienced',
#  'build',
#  'tool',
#  'ant',
#  'maven',
#  '•',
#  'experienced',
#  'using',
#  'testing',
#  'framework',
#  'junit',
#  'jmockit',
#  '•',
#  'experienced',
#  'using',
#  'logging',
#  'tool',
#  'intellij',
#  'log4j',
#  '•',
#  'hand',
#  'experience',
#  'web/application',
#  'server',
#  'apache',
#  'tomcat',
#  'jboss',
#  'weblogic',
#  'web',
#  'sphere',
#  '•',
#  'experienced',
#  'developing',
#  'various',
#  'uml',
#  'design',
#  'class',
#  'diagram',
#  'sequence',
#  'diagram',
#  ...]

# %%
def get_key_word(x):
    finder = BigramCollocationFinder.from_words(x)
    lst = []
    Key_word_from_CV = []
    for i in sorted(finder.ngram_fd.items()):
    # if a double word appears more than once, then print it out.
        if i[1] > 1:
            print(i)
            lst.append(i[0])
        else:
            pass

    # print("************************")
    for j in lst:
    #     print(" ".join(j))
        Key_word_from_CV.append(" ".join(j))
    return Key_word_from_CV

# %%
key_word = get_key_word(NLP_Processed_CV)
key_word
# Out:
# (('-the-fly', 'configuration'), 3)
# (('-till', 'date'), 4)
# (('.xml', 'file'), 5)
# (('/10g,11g', 'hsql'), 4)
# (('1.3', '1.4'), 2)
# (('1.4', 'using'), 2)
# (('2.0', 'mobile'), 4)
# (('2.0', 'standard'), 3)
# (('2.0.47', 'ihs'), 3)
# (('2.5', 'mvc'), 2)
# (('2000', 'professional'), 5)
# (('2003', 'server'), 5)
# (('2009', 'technical'), 5)
# (('2012', 'july2014'), 2)
# (('2014', 'aug'), 3)
# (('2015', 'role'), 3)
# (('2015–aug', '2016'), 3)
# (('2016', 'role'), 3)
# (('6.0', 'apache'), 3)
# (('6.0', 'window'), 3)
# (('6.0/6.1', 'academic'), 3)
# (('6.0/6.1', 'websphere'), 3)
# (('6.0/6.1', '•'), 3)
# (('6.0/6.1/7.0', 'websphere'), 3)
# (('8+', 'experience'), 5)
# (('9.design', 'pattern'), 4)
# (('9/10', 'red'), 4)
# (('95/98/nt/2000/xp', 'sun'), 4)
# (('9i', '/10g,11g'), 4)
# (('academic', 'bank'), 3)
# (('access', 'display'), 3)
# (('access', 'manager'), 2)
# (('accessibility', 'web'), 3)
# (('accommodate', 'advanced'), 2)
# (('achieved', 'proficiency'), 3)
# (('act', 'front'), 3)
# (('actively', 'participated'), 2)
# (('add', 'feature'), 2)
# (('add', 'modal'), 2)
# (('admin', 'console'), 3)
# (('admin', 'server'), 2)
# (('administered', 'websphere'), 3)
# (('adobe', 'flash'), 4)
# (('adopted', 'wcag'), 3)
# (('advanced', 'fast'), 2)
# (('agile', 'methodology'), 10)
# (('agile', 'scrum'), 4)
# (('ajax', 'increase'), 2)
# (('ajax', 'javascript'), 3)
# (('analysis', 'design'), 5)
# (('analytics', 'using'), 3)
# (('angular', 'j'), 3)
# (('angular.js', 'development'), 4)
# (('angular.js', 'node.js'), 7)
# (('angularjs', 'jquery'), 5)
# (('ant', 'maven'), 5)
# (('ant', 'pl/sq'), 5)
# (('anudeep', 'sr'), 4)
# (('anudeepreddynallamada', 'gmail.com'), 5)
# (('aop', 'spring'), 4)
# (('apache', '2.0.47'), 3)
# (('apache', 'soap'), 2)
# (('apache', 'tomcat'), 5)
# (('apis', 'analytics'), 3)
# (('app', 'management'), 3)
# (('app', 'usage'), 3)
# (('application', 'access'), 3)
# (('application', 'anudeep'), 2)
# (('application', 'backbone'), 2)
# (('application', 'based'), 5)
# (('application', 'code'), 2)
# (('application', 'deployment'), 3)
# (('application', 'development'), 4)
# (('application', 'functionality'), 2)
# (('application', 'responding'), 3)
# (('application', 'saved'), 3)
# (('application', 'server'), 25)
# (('application', 'specific'), 3)
# (('application', 'usage'), 4)
# (('application', 'using'), 19)
# (('application', 'web'), 2)
# (('application', 'websphere'), 3)
# (('application', '•'), 7)
# (('applied', 'industry'), 2)
# (('architect', 'back-end'), 2)
# (('architect', 'develop'), 2)
# (('architecture', 'using'), 12)
# (('architecture', '•'), 10)
# (('assemble', 'develop'), 4)
# (('aug', '2014'), 3)
# (('aug', '2015'), 3)
# (('axis', 'integration'), 4)
# (('axis', 'jwsdp'), 4)
# (('axis', 'soap'), 2)
# (('bachelor', 'engineering'), 5)
# (('back-end', 'developer'), 2)
# (('backbone', 'j'), 2)
# (('backbone.js', 'require.js'), 2)
# (('backend', 'service'), 3)
# (('bandwidth', 'usage'), 2)
# (('bank', 'kansa'), 3)
# (('bar', 'ie'), 2)
# (('base', 'uml'), 2)
# (('based', 'interactive'), 3)
# (('based', 'oops'), 5)
# (('bean', 'middle'), 2)
# (('bean', 'servlets'), 5)
# (('bitbucket', 'maven'), 4)
# (('boot', 'pl/sql'), 3)
# (('boot', 'spring'), 4)
# (('browser', 'compatibility'), 2)
# (('browser', 'standard'), 3)
# (('build', 'management'), 4)
# (('build', 'tool'), 5)
# (('build', 'using'), 3)
# (('building', 'rich'), 2)
# (('built', 'data'), 3)
# (('built', 'mobile'), 3)
# (('business', 'delegate'), 4)
# (('business', 'layer'), 6)
# (('business', 'logic'), 4)
# (('c++', 'agile'), 2)
# (('c++', 'java/j2ee'), 5)
# (('c++', 'multi-threaded'), 2)
# (('car', 'dealership'), 3)
# (('cascading', 'style'), 5)
# (('change', 'set'), 3)
# (('checking', 'jvm'), 2)
# (('chrome', 'oracle'), 2)
# (('ci/cd', 'jenkins'), 3)
# (('city', 'mo'), 3)
# (('class', 'diagram'), 5)
# (('class', 'framework'), 4)
# (('class', 'path'), 2)
# (('class', 'sequence'), 2)
# (('clean', 'separation'), 4)
# (('client', 'contract'), 3)
# (('client', 'develop'), 2)
# (('client-server', 'architecture'), 5)
# (('client-side', 'interface'), 3)
# (('client-side', 'javascript'), 4)
# (('closely', 'developer'), 2)
# (('cloud', 'built'), 3)
# (('clustered', 'environment'), 2)
# (('clustering', 'performance'), 3)
# (('clustering', 'web'), 2)
# (('code', 'defect'), 2)
# (('code', 'github'), 3)
# (('code', 'jdk'), 2)
# (('code', 'match'), 3)
# (('code', 'modifying'), 3)
# (('code', 'review'), 4)
# (('code', '•'), 4)
# (('collection', 'developing'), 4)
# (('collection', 'multithreading'), 3)
# (('color', 'scheme'), 2)
# (('commands.java', 'technology'), 5)
# (('commerce', 'server'), 6)
# (('communicate', 'business'), 2)
# (('communication', 'component'), 2)
# (('communication', 'dallas'), 4)
# (('compatibility', 'accommodate'), 2)
# (('component', '•'), 2)
# (('comprehensively', 'test'), 3)
# (('computer', 'science'), 5)
# (('concept', 'collection'), 4)
# (('concurrency', 'exception'), 3)
# (('configuration', 'build'), 4)
# (('configuration', 'change'), 3)
# (('configured', 'administered'), 3)
# (('configured', 'application'), 5)
# (('conjunction', 'spring'), 2)
# (('console', 'wscp/wsadmin'), 3)
# (('container', 'parameter'), 3)
# (('continuous', 'integration'), 3)
# (('contract', 'summarize'), 3)
# (('control', 'mvc'), 4)
# (('control', 'tool'), 6)
# (('controller', 'architecture'), 5)
# (('controller', 'session'), 4)
# (('controller', '•'), 2)
# (('core', 'dependency'), 4)
# (('core', 'java'), 10)
# (('core', 'json'), 3)
# (('core', 'spring'), 4)
# (('created', '-the-fly'), 3)
# (('created', 'build'), 3)
# (('created', 'image'), 2)
# (('created', 'site'), 3)
# (('created', 'user'), 2)
# (('created', 'web'), 3)
# (('creating', 'java'), 3)
# (('cs', 'html'), 3)
# (('cs', 'jquery'), 3)
# (('cs', 'requirement'), 4)
# (('cs', 'spring'), 4)
# (('cs', 'style'), 4)
# (('cs', 'xml'), 3)
# (('cs', 'xslt.xml'), 5)
# (('cs', '•'), 8)
# (('css3', 'etc'), 2)
# (('css3', 'javascript'), 2)
# (('css3', 'shell'), 4)
# (('css3', 'style'), 2)
# (('custom', 'tag'), 5)
# (('cv', '•'), 5)
# (('cycle', 'initiation'), 5)
# (('d3.js', 'jquery'), 3)
# (('d3.js', 'mysql'), 3)
# (('dallas', 'texassep'), 3)
# (('dallas', 'tx'), 4)
# (('dao', 'dto'), 4)
# (('dao', 'pattern'), 4)
# (('dao', 'spring'), 4)
# (('data', '.xml'), 5)
# (('data', 'communicate'), 2)
# (('data', 'processing'), 3)
# (('data', 'storage'), 4)
# (('data', 'support'), 3)
# (('data', 'using'), 3)
# (('data', 'visualization'), 3)
# (('database', 'host'), 3)
# (('date', 'role'), 4)
# (('db', 'spring'), 3)
# (('db2', 'pl/sql'), 4)
# (('db2', 'toad'), 4)
# (('dealership', 'website'), 3)
# (('debugged', 'application'), 2)
# (('decorator', 'factory'), 4)
# (('defect', 'deployment'), 2)
# (('define', 'configured'), 2)
# (('delegate', 'observer'), 4)
# (('dependency', 'injection'), 9)
# (('deploy', 'java'), 4)
# (('deployment', 'class'), 2)
# (('deployment', 'ejbs'), 2)
# (('deployment', 'error'), 3)
# (('design', 'class'), 5)
# (('design', 'develop'), 5)
# (('design', 'development'), 5)
# (('design', 'html5/css3'), 2)
# (('design', 'pattern'), 5)
# (('design', 'using'), 2)
# (('designed', 'apis'), 3)
# (('designed', 'dom'), 3)
# (('designed', 'frontend'), 2)
# (('designing', 'developing'), 5)
# (('designing', 'execution'), 5)
# (('designing', 'ui'), 4)
# (('desktop', 'application'), 3)
# (('develop', 'deploy'), 4)
# (('develop', 'front-end'), 2)
# (('develop', 'layout'), 2)
# (('develop', 'solution'), 2)
# (('develop', 'test'), 3)
# (('developed', 'application'), 4)
# (('developed', 'css3'), 2)
# (('developed', 'navigation'), 4)
# (('developed', 'page'), 2)
# (('developed', 'project'), 5)
# (('developed', 'using'), 2)
# (('developer', 'define'), 2)
# (('developer', 'gather'), 2)
# (('developer', 'junit'), 5)
# (('developer', 'studio'), 5)
# (('developer', 'tool'), 6)
# (('developing', 'application'), 6)
# (('developing', 'n-tier'), 5)
# (('developing', 'server-side'), 4)
# (('developing', 'user'), 5)
# (('developing', 'various'), 5)
# (('development', 'cs'), 4)
# (('development', 'designing'), 4)
# (('development', 'etc'), 3)
# (('development', 'life'), 5)
# (('development', 'testing'), 5)
# (('development', 'tile'), 5)
# (('development', 'using'), 4)
# (('development', '•'), 2)
# (('development.scripting/gui', 'tool'), 4)
# (('dhtml', 'dojo'), 4)
# (('dhtml', 'ext'), 2)
# (('dhtml', 'xml'), 10)
# (('diagram', 'developed'), 2)
# (('diagram', 'sequence'), 5)
# (('diagram', 'using'), 5)
# (('dialog', 'web'), 2)
# (('display', 'data'), 3)
# (('dml', 'dhtml'), 2)
# (('document', 'manipulated'), 2)
# (('dojo', 'json'), 4)
# (('dom', 'based'), 3)
# (('dom', 'dml'), 2)
# (('dom', 'dom'), 2)
# (('dom', 'function'), 2)
# (('dom', 'parsers.ides'), 5)
# (('dreamweaver', 'm'), 4)
# (('dreamweaver', 'xml'), 2)
# (('dreamweaver', '•'), 2)
# (('driven', 'development'), 3)
# (('driven', 'development.scripting/gui'), 4)
# (('driver', 'servlet'), 2)
# (('dtd', 'jaxp'), 5)
# (('dto', 'front'), 4)
# (('due', 'memory'), 3)
# (('dwr', 'log4j.web'), 4)
# (('ear', 'war'), 3)
# (('eclipse', 'ibm'), 3)
# (('eclipse', 'ide'), 3)
# (('eclipse', 'netbeans'), 12)
# (('eclipse', 'using'), 4)
# (('education', 'bachelor'), 5)
# (('ee', 'web'), 4)
# (('effect', 'developed'), 2)
# (('effect', 'development'), 4)
# (('ejbs', 'multiple'), 2)
# (('elasticsearch', 'logstash'), 4)
# (('ember.js', 'd3.js'), 3)
# (('engineering', 'computer'), 5)
# (('engineering', 'jntu'), 5)
# (('engines-as', 'deployment'), 2)
# (('enhance', 'application'), 2)
# (('enhance', 'portal'), 4)
# (('enhanced', 'design'), 2)
# (('environment', 'html'), 3)
# (('environment', 'html5'), 2)
# (('environment', 'java'), 4)
# (('environment', '•'), 3)
# (('error', 'wrong'), 3)
# (('esb', 'axis'), 4)
# (('etc', 'tackled'), 2)
# (('etc', '•'), 3)
# (('exception', 'handling'), 3)
# (('execution', 'implementation'), 5)
# (('exhaustive', 'test'), 3)
# (('existing', 'application'), 3)
# (('existing', 'code'), 3)
# (('experience', 'concurrency'), 3)
# (('experience', 'designing'), 5)
# (('experience', 'developing'), 5)
# (('experience', 'garbage'), 3)
# (('experience', 'jsp'), 5)
# (('experience', 'using'), 10)
# (('experience', 'web/application'), 5)
# (('experience', 'wind'), 4)
# (('experienced', 'build'), 5)
# (('experienced', 'developing'), 5)
# (('experienced', 'persistence'), 5)
# (('experienced', 'processing'), 5)
# (('experienced', 'using'), 10)
# (('explorer', 'firefox'), 2)
# (('exposure', 'implementing'), 5)
# (('ext', 'j'), 2)
# (('ext.js', '•'), 2)
# (('extjs', 'building'), 2)
# (('extracting', 'data'), 5)
# (('factory', 'pattern'), 8)
# (('fast', 'technology'), 2)
# (('façade', 'business'), 4)
# (('feature', 'environment'), 2)
# (('file', 'handling'), 3)
# (('file', 'server'), 3)
# (('file', '•'), 8)
# (('final', 'interface'), 2)
# (('financial', 'data'), 3)
# (('firebug', 'traverse'), 2)
# (('firefox', 'chrome'), 2)
# (('firefox', 'ie'), 2)
# (('flash', 'photoshop'), 4)
# (('flattening', 'object'), 4)
# (('flow', 'spring'), 4)
# (('frame', 'conjunction'), 2)
# (('frame', 'using'), 4)
# (('framework', 'angular.js'), 2)
# (('framework', 'enhanced'), 2)
# (('framework', 'hibernate'), 5)
# (('framework', 'implementing'), 2)
# (('framework', 'junit'), 5)
# (('framework', 'presentation'), 3)
# (('framework', '•'), 12)
# (('front', 'controller'), 7)
# (('front', 'javascript'), 3)
# (('front-end', 'interface'), 2)
# (('frontend', 'object'), 2)
# (('frontpage', 'vbscript'), 4)
# (('function', 'using'), 2)
# (('functionality', 'add'), 2)
# (('functionality', 'code'), 3)
# (('functionality', '•'), 4)
# (('garbage', 'collection'), 3)
# (('gather', 'data'), 2)
# (('gather', 'requirement'), 2)
# (('gathering', 'analysis'), 5)
# (('git', 'bitbucket'), 4)
# (('github', 'repository'), 3)
# (('gmail.com', 'professional'), 5)
# (('gradient', 'effect'), 6)
# (('graphana', 'git'), 4)
# (('gui', 'using'), 3)
# (('hand', 'experience'), 5)
# (('handling', 'environment'), 3)
# (('handling', 'file'), 3)
# (('hanging', 'owner'), 3)
# (('hat', 'developer'), 5)
# (('hat', 'linux'), 4)
# (('helper', 'decorator'), 4)
# (('hibernate', 'dwr'), 4)
# (('hibernate', 'frame'), 2)
# (('hibernate', 'hibernate'), 4)
# (('hibernate', 'java'), 3)
# (('hibernate', 'orm'), 9)
# (('hibernate', 'persistence'), 4)
# (('horizontal', 'vertical'), 3)
# (('host', 'name'), 3)
# (('host', 'web'), 2)
# (('hsql', 'sybase'), 4)
# (('html', 'cs'), 11)
# (('html', 'dhtml'), 10)
# (('html', 'javascript'), 5)
# (('html', 'jsp'), 2)
# (('html', 'xhtml'), 3)
# (('html', '•'), 6)
# (('html5', 'css3'), 4)
# (('html5', 'dhtml'), 4)
# (('html5/css3', 'javascript'), 2)
# (('hung', 'due'), 3)
# (('hyderabad', 'india'), 8)
# (('ibm', 'cloud'), 3)
# (('ibm', 'dallas'), 3)
# (('ibm', 'db2'), 4)
# (('ibm', 'mobile'), 3)
# (('ibm', 'web'), 9)
# (('ibm', 'websphere'), 3)
# (('icon', 'applied'), 2)
# (('icon', 'layout'), 4)
# (('icon', 'web'), 2)
# (('ides', 'eclipse'), 5)
# (('ie', 'developer'), 2)
# (('ie', '•'), 2)
# (('ihs', '6.0/6.1'), 3)
# (('image', 'logo'), 2)
# (('implement', 'web'), 2)
# (('implementation', 'business'), 4)
# (('implementation', 'clean'), 4)
# (('implementation', 'maintenance'), 5)
# (('implementation', 'web'), 4)
# (('implementation', '•'), 4)
# (('implemented', 'client-side'), 3)
# (('implemented', 'final'), 2)
# (('implemented', 'horizontal'), 3)
# (('implemented', 'mvc'), 2)
# (('implemented', 'object-relation'), 2)
# (('implemented', 'web'), 4)
# (('implementing', 'jstl'), 5)
# (('implementing', 'web'), 7)
# (('improve', 'speed'), 2)
# (('in-browser', 'load'), 2)
# (('increase', 'web'), 2)
# (('india', '2009'), 5)
# (('india', 'june'), 2)
# (('industry', 'practice'), 2)
# (('initiation', 'planning'), 5)
# (('injection', 'spring'), 4)
# (('injection', '•'), 5)
# (('input', 'request'), 2)
# (('insight', 'app'), 3)
# (('installed', 'configured'), 3)
# (('installed', 'ear'), 3)
# (('instance', 'websphere'), 2)
# (('instance', '•'), 5)
# (('integration', 'system'), 4)
# (('integration', 'tool'), 3)
# (('intellij', 'log4j'), 5)
# (('interactive', 'reprogram'), 3)
# (('interactivity', 'speed'), 2)
# (('interface', 'class'), 2)
# (('interface', 'design'), 2)
# (('interface', 'html'), 5)
# (('interface', 'ui'), 2)
# (('interface', 'using'), 3)
# (('internet', 'application'), 2)
# (('internet', 'explorer'), 2)
# (('internet', 'intranet'), 5)
# (('intranet', 'client-server'), 5)
# (('involved', 'application'), 4)
# (('involved', 'gui'), 3)
# (('involved', 'issue'), 3)
# (('involved', 'sdlc'), 3)
# (('involved', 'service'), 4)
# (('involved', 'stopping/starting'), 3)
# (('involved', 'using'), 3)
# (('ioc', 'spring'), 4)
# (('ireport.operating', 'system'), 4)
# (('issue', 'application'), 3)
# (('issue', 'checking'), 2)
# (('issue', 'java'), 2)
# (('issue', 'related'), 2)
# (('issue', '•'), 3)
# (('j', 'angular.js'), 2)
# (('j', 'eclipse'), 3)
# (('j', 'optimize'), 2)
# (('j', 'redux'), 3)
# (('j', 'require'), 2)
# (('j2ee', 'java'), 3)
# (('j2ee', 'jsp'), 5)
# (('j2ee', 'technology'), 4)
# (('java', 'bean'), 5)
# (('java', 'code'), 6)
# (('java', 'concept'), 4)
# (('java', 'cs'), 3)
# (('java', 'ee'), 4)
# (('java', 'j2ee'), 9)
# (('java', 'jsp'), 3)
# (('java', 'mail'), 5)
# (('java', 'platform'), 4)
# (('java', 'programmer'), 17)
# (('java', 'script'), 8)
# (('java/j2ee', 'pl/sql'), 5)
# (('java/j2ee', 'supporting'), 5)
# (('java1.8.web', 'technology'), 5)
# (('javabeans', 'jndi'), 5)
# (('javascript', 'angular.js'), 4)
# (('javascript', 'css3'), 4)
# (('javascript', 'file'), 3)
# (('javascript', 'framework'), 2)
# (('javascript', 'html'), 5)
# (('javascript', 'jquery'), 10)
# (('javascript', 'using'), 2)
# (('javascript', 'validation'), 4)
# (('javascript', 'xml'), 6)
# (('jax-rpc', 'jax-ws'), 4)
# (('jax-rs', 'esb'), 4)
# (('jax-ws', 'jax-rs'), 4)
# (('jaxp', 'sax'), 5)
# (('jboss', 'weblogic'), 5)
# (('jdbc', 'driver'), 2)
# (('jdbc', 'jms'), 5)
# (('jdbc', 'spring'), 4)
# (('jdk', '1.3'), 2)
# (('jenkins', 'created'), 3)
# (('jenkins.professional', 'experience'), 4)
# (('jmockit', '•'), 5)
# (('jms', 'communication'), 2)
# (('jms', 'javabeans'), 5)
# (('jndi', 'java'), 5)
# (('jntu', 'hyderabad'), 5)
# (('jquery', 'angular'), 3)
# (('jquery', 'dom'), 2)
# (('jquery', 'javascript'), 9)
# (('jquery', 'mysql'), 3)
# (('jquery', 'react.js'), 6)
# (('jquery', '•'), 5)
# (('jsf', 'framework'), 2)
# (('jsf', 'implementing'), 5)
# (('jsf', 'portal'), 3)
# (('json', 'javascript'), 4)
# (('json', 'servlets'), 3)
# (('jsp', 'cs'), 4)
# (('jsp', 'java'), 8)
# (('jsp', 'jquery'), 4)
# (('jsp', 'jsp'), 2)
# (('jsp', 'nodejsadditional'), 4)
# (('jsp', 'servlet'), 5)
# (('jsp', 'spring'), 3)
# (('jsp', 'standard'), 5)
# (('jsp', 'tag'), 2)
# (('jstl', 'java'), 2)
# (('jstl', 'jsp'), 9)
# (('july2014', 'role'), 2)
# (('june', '2012'), 2)
# (('junit', 'ireport.operating'), 4)
# (('junit', 'jmockit'), 5)
# (('jvm', 'log'), 2)
# (('jvm', 'setting'), 3)
# (('jwsdp', 'restful'), 4)
# (('kansa', 'city'), 3)
# (('kibana', 'graphana'), 4)
# (('lab', 'hyderabad'), 2)
# (('lagging', '•'), 2)
# (('language', 'c++'), 5)
# (('language', 'javascript'), 5)
# (('layer', 'persistent'), 4)
# (('layer', 'usage'), 4)
# (('layer', 'using'), 8)
# (('layout', 'color'), 2)
# (('layout', 'navigation'), 2)
# (('layout', '•'), 4)
# (('lib', 'jstl'), 2)
# (('library', 'custom'), 5)
# (('life', 'cycle'), 5)
# (('lightweight', 'set'), 4)
# (('link', 'adopted'), 3)
# (('linux', '9.design'), 4)
# (('linux', 'platform'), 3)
# (('linux', '•'), 5)
# (('load', 'module'), 2)
# (('load', 'time'), 2)
# (('load', 'web'), 3)
# (('log', 'application'), 5)
# (('log', 'plug-in'), 2)
# (('log', 'webserver'), 2)
# (('log', '•'), 2)
# (('log4j', 'jquery'), 3)
# (('log4j', '•'), 5)
# (('log4j.web', 'service'), 4)
# (('logging', 'tool'), 5)
# (('logic', 'application'), 3)
# (('logic', 'validation'), 4)
# (('logo', 'icon'), 2)
# (('logstash', 'kibana'), 4)
# (('m', 'frontpage'), 4)
# (('m', 'visio'), 5)
# (('mail', 'java1.8.web'), 5)
# (('maintained', 'security'), 2)
# (('maintenance', 'education'), 5)
# (('management', 'application'), 4)
# (('management', 'insight'), 3)
# (('manager', '•'), 2)
# (('manipulated', 'node'), 2)
# (('mapping', 'orm'), 4)
# (('mapping', 'persistence'), 2)
# (('mapping', 'typical'), 5)
# (('match', 'front'), 3)
# (('maven', 'jenkins.professional'), 4)
# (('maven', 'pulled'), 3)
# (('maven', 'xmlspy'), 5)
# (('maven', '•'), 9)
# (('meet', 'accessibility'), 3)
# (('memory', 'thread'), 3)
# (('mentoring', 'requirement'), 2)
# (('methodology', 'modeled'), 2)
# (('methodology', 'scrum'), 3)
# (('methodology', 'sdlc'), 5)
# (('methodology', 'value'), 2)
# (('microsoft', 'visio'), 2)
# (('middle', 'tier'), 2)
# (('migrated', 'existing'), 3)
# (('mo', 'aug'), 3)
# (('mobile', 'application'), 4)
# (('mobile', 'backend'), 3)
# (('mobile', '•'), 3)
# (('mock', 'test'), 3)
# (('modal', 'dialog'), 2)
# (('model', 'application'), 2)
# (('model', 'view'), 9)
# (('modeled', 'architect'), 2)
# (('modifying', 'existing'), 3)
# (('module', 'improve'), 2)
# (('mongodb', 'sql'), 4)
# (('monitor', 'file'), 3)
# (('monitored', 'log'), 2)
# (('monitoring', 'log'), 3)
# (('monthly', 'financial'), 3)
# (('mssql', 'mongodb'), 4)
# (('multi-threaded', 'shell'), 2)
# (('multiple', 'instance'), 2)
# (('multithreading', '•'), 3)
# (('mvc', 'architecture'), 7)
# (('mvc', 'business'), 4)
# (('mvc', 'core'), 3)
# (('mvc', 'dao'), 4)
# (('mvc', 'framework'), 6)
# (('mvc', 'jsp'), 4)
# (('mvc', 'model'), 5)
# (('mvc', 'spring'), 4)
# (('mvc', 'structure'), 4)
# (('mvc', '•'), 4)
# (('mysql', 'db'), 3)
# (('mysql', 'mssql'), 4)
# (('mysql', '•'), 6)
# (('n-tier', 'application'), 5)
# (('n-tier', 'architecture'), 5)
# (('name', 'server'), 3)
# (('navigation', 'icon'), 6)
# (('netbeans', 'rad'), 5)
# (('netbeans', 'red'), 5)
# (('node', 'using'), 2)
# (('node.js', 'backbone.js'), 2)
# (('node.js', 'environment'), 3)
# (('node.js', 'ext.js'), 2)
# (('node.js', 'java'), 3)
# (('nodejsadditional', 'skill'), 4)
# (('object', 'oriented'), 7)
# (('object', 'pooldatabases'), 4)
# (('object', 'relational'), 5)
# (('object', 'table'), 4)
# (('object', '•'), 4)
# (('object-relation', 'mapping'), 2)
# (('observer', 'singleton'), 4)
# (('one-on-one', 'client'), 2)
# (('oops', 'object'), 5)
# (('optimize', 'in-browser'), 2)
# (('optimize', 'performance'), 2)
# (('oracle', 'window'), 2)
# (('oracle8', '9i'), 4)
# (('organize', 'client'), 3)
# (('oriented', 'javascript'), 2)
# (('oriented', 'programming'), 6)
# (('orm', 'object'), 9)
# (('orm', 'tool'), 4)
# (('owner', 'ship'), 3)
# (('page', 'interactivity'), 2)
# (('page', 'layout'), 2)
# (('page', 'reducing'), 2)
# (('page', 'user'), 2)
# (('page', 'using'), 2)
# (('parameter', 'using'), 3)
# (('parsers.ides', 'tool'), 5)
# (('parsing', 'extracting'), 5)
# (('participated', 'mentoring'), 2)
# (('path', 'issue'), 2)
# (('pattern', 'factory'), 4)
# (('pattern', 'mvc'), 4)
# (('pattern', 'pom'), 4)
# (('pattern', 'singleton'), 4)
# (('pattern', '•'), 4)
# (('performance', 'tuning'), 3)
# (('performance', 'using'), 2)
# (('persistence', 'framework'), 9)
# (('persistence', 'layer'), 2)
# (('persistent', 'layer'), 4)
# (('phase', '•'), 2)
# (('photoshop', 'dreamweaver'), 2)
# (('photoshop', '•'), 2)
# (('pl/sq', 'developer'), 5)
# (('pl/sql', 'log4j'), 3)
# (('pl/sql', 'query'), 4)
# (('pl/sql', 'shell'), 5)
# (('planning', 'designing'), 5)
# (('platform', 'model'), 4)
# (('platform', 'window'), 5)
# (('platform', '•'), 3)
# (('plug-in', 'log'), 2)
# (('pom', 'object'), 4)
# (('pooldatabases', 'tool'), 4)
# (('portal', 'framework'), 3)
# (('portal', 'server'), 3)
# (('portal', 'ui'), 4)
# (('portion', 'web'), 2)
# (('postman', '•'), 4)
# (('powerful', 'app'), 3)
# (('practice', 'standard'), 2)
# (('prepared', 'exhaustive'), 3)
# (('presentation', 'tier'), 3)
# (('processing', 'using'), 3)
# (('processing', 'validating'), 5)
# (('product', 'using'), 5)
# (('professional', '8+'), 5)
# (('professional', 'summary'), 5)
# (('professional', 'window'), 5)
# (('proficiency', 'unit'), 3)
# (('programmer', 'anudeepreddynallamada'), 5)
# (('programmer', 'responsibility'), 12)
# (('programming', 'internet'), 5)
# (('project', 'code'), 3)
# (('project', 'product'), 5)
# (('project', 'requirement'), 2)
# (('protocol', '•'), 5)
# (('providing', 'client-side'), 4)
# (('pulled', 'project'), 3)
# (('query', '•'), 4)
# (('rad', 'eclipse'), 2)
# (('rad', 'redeployed'), 2)
# (('rad', 'wsad'), 5)
# (('rad', '•'), 5)
# (('rational', 'rose'), 10)
# (('react', 'j'), 3)
# (('react.js', 'angular.js'), 3)
# (('react.js', 'ember.js'), 3)
# (('react.js', 'meet'), 3)
# (('red', 'hat'), 9)
# (('redeployed', 'clustered'), 2)
# (('reducing', 'bandwidth'), 2)
# (('redux', '•'), 3)
# (('related', 'browser'), 2)
# (('relational', 'mapping'), 5)
# (('remote', 'model'), 2)
# (('repository', '•'), 3)
# (('reprogram', 'selected'), 3)
# (('request', '•'), 2)
# (('require', 'j'), 2)
# (('require.js', 'adobe'), 2)
# (('requirement', 'enhance'), 6)
# (('requirement', 'gathering'), 5)
# (('requirement', 'lagging'), 2)
# (('resource', 'servlets'), 2)
# (('responding', 'application'), 3)
# (('responsibility', '•'), 12)
# (('responsible', 'providing'), 4)
# (('restful', 'web'), 3)
# (('restful', 'webservices.implementationsmethodologies'), 4)
# (('review', 'configuration'), 4)
# (('rich', 'internet'), 2)
# (('role', 'java'), 6)
# (('role', 'sr'), 7)
# (('rose', 'm'), 5)
# (('rose', '•'), 5)
# (('saved', 'node.js'), 3)
# (('sax', 'dom'), 5)
# (('schema', 'dtd'), 5)
# (('scheme', 'website'), 2)
# (('science', 'engineering'), 5)
# (('script', 'dreamweaver'), 4)
# (('script', 'html'), 3)
# (('script', 'mysql'), 3)
# (('script', 'unix'), 5)
# (('script', '•'), 5)
# (('scripting', 'language'), 5)
# (('scripting', '•'), 2)
# (('scrum', 'test'), 4)
# (('scrum', '•'), 3)
# (('sdlc', 'requirement'), 3)
# (('sdlc', 'software'), 5)
# (('seal', 'tivoli'), 2)
# (('security', 'tuning'), 2)
# (('selected', 'link'), 3)
# (('sep-2016', '-till'), 4)
# (('separation', 'layer'), 4)
# (('sequence', 'diagram'), 7)
# (('serialization', 'flattening'), 4)
# (('server', '6.0'), 6)
# (('server', '6.0/6.1'), 6)
# (('server', '6.0/6.1/7.0'), 3)
# (('server', 'apache'), 5)
# (('server', 'developer'), 4)
# (('server', 'hung'), 3)
# (('server', 'ibm'), 7)
# (('server', 'instance'), 5)
# (('server', 'load'), 3)
# (('server', 'speed'), 3)
# (('server', 'start-up'), 2)
# (('server', 'using'), 2)
# (('server', 'virtual'), 2)
# (('server', 'websphere'), 3)
# (('server', 'window'), 5)
# (('server-side', 'service'), 4)
# (('server.frameworks', 'strut'), 4)
# (('service', 'class'), 4)
# (('service', 'desktop'), 3)
# (('service', 'optimize'), 2)
# (('service', 'powerful'), 3)
# (('service', 'specification'), 4)
# (('service', 'using'), 9)
# (('service', '•'), 4)
# (('services-wsdl', 'using'), 5)
# (('servlet', 'act'), 3)
# (('servlet', 'engines-as'), 2)
# (('servlet', 'jdbc'), 5)
# (('servlets', 'developing'), 5)
# (('servlets', 'jdbc'), 2)
# (('servlets', 'webservices'), 3)
# (('session', 'bean'), 2)
# (('session', 'façade'), 4)
# (('set', 'application'), 3)
# (('set', 'tool'), 4)
# (('setting', 'web'), 3)
# (('sheet', 'cs'), 5)
# (('sheet', 'developed'), 4)
# (('sheet', 'gradient'), 2)
# (('shell', 'script'), 9)
# (('shell', 'scripting'), 2)
# (('ship', 'issue'), 3)
# (('singleton', 'dao'), 4)
# (('singleton', 'view'), 4)
# (('site', 'organize'), 3)
# (('skill', 'elasticsearch'), 4)
# (('skill', 'language'), 5)
# (('soap', 'hibernate'), 3)
# (('soap', 'implement'), 2)
# (('soap', 'internet'), 2)
# (('soap', 'jms'), 2)
# (('soap', 'protocol'), 5)
# (('soap', 'soap'), 2)
# (('software', 'development'), 5)
# (('solaris', '9/10'), 4)
# (('solution', 'using'), 2)
# (('specific', 'jvm'), 3)
# (('specification', 'jax-rpc'), 4)
# (('speed', 'data'), 3)
# (('speed', 'functionality'), 2)
# (('speed', '•'), 2)
# (('sphere', 'application'), 9)
# (('sphere', '•'), 5)
# (('spring', '2.5'), 3)
# (('spring', 'aop'), 4)
# (('spring', 'boot'), 7)
# (('spring', 'core'), 8)
# (('spring', 'dao'), 4)
# (('spring', 'dependency'), 4)
# (('spring', 'framework'), 2)
# (('spring', 'hibernate'), 4)
# (('spring', 'ioc'), 4)
# (('spring', 'jdbc'), 4)
# (('spring', 'jsf'), 5)
# (('spring', 'mvc'), 23)
# (('spring', 'web'), 4)
# (('sql', 'server'), 4)
# (('sql', 'server.frameworks'), 4)
# (('sr', 'java'), 12)
# (('standard', 'car'), 3)
# (('standard', 'cs'), 3)
# (('standard', 'html'), 3)
# (('standard', 'project'), 2)
# (('standard', 'tag'), 5)
# (('start-up', 'issue'), 2)
# (('stateless', 'session'), 2)
# (('stopping/starting', 'monitoring'), 3)
# (('storage', 'using'), 4)
# (('stream', 'communication'), 4)
# (('strong', 'experience'), 10)
# (('structure', 'implementation'), 4)
# (('strut', 'spring'), 4)
# (('studio', 'rad'), 5)
# (('style', 'sheet'), 11)
# (('summarize', 'monthly'), 3)
# (('summary', '•'), 5)
# (('sun', 'solaris'), 4)
# (('support', 'team'), 3)
# (('supporting', 'technology'), 5)
# (('svn', 'cv'), 5)
# (('swing', 'html'), 2)
# (('sybase', 'mysql'), 4)
# (('system', 'window'), 4)
# (('system', '•'), 4)
# (('table', 'using'), 4)
# (('tackled', 'various'), 2)
# (('tag', 'development'), 5)
# (('tag', 'lib'), 2)
# (('tag', 'library'), 5)
# (('team', 'architect'), 2)
# (('team', 'using'), 3)
# (('technical', 'skill'), 5)
# (('technology', 'angularjs'), 5)
# (('technology', 'core'), 5)
# (('technology', 'html5'), 2)
# (('technology', 'spring'), 4)
# (('technology', 'xml'), 5)
# (('technology', '•'), 7)
# (('test', 'comprehensively'), 3)
# (('test', 'driven'), 7)
# (('test', 'functionality'), 3)
# (('test', 'html'), 3)
# (('test', 'mock'), 3)
# (('testing', 'application'), 3)
# (('testing', 'framework'), 5)
# (('testing', 'phase'), 2)
# (('testing', 'web'), 4)
# (('texassep', '2015–aug'), 3)
# (('thread', 'hanging'), 3)
# (('tier', 'application'), 6)
# (('tier', 'development'), 2)
# (('tier', 'servlet'), 3)
# (('tile', '•'), 5)
# (('time', 'add'), 2)
# (('tivoli', 'access'), 2)
# (('toad', 'maven'), 5)
# (('toad', 'sql'), 4)
# (('tomcat', 'jboss'), 5)
# (('tool', 'ant'), 5)
# (('tool', 'assemble'), 4)
# (('tool', 'bar'), 2)
# (('tool', 'ci/cd'), 3)
# (('tool', 'eclipse'), 9)
# (('tool', 'html5'), 4)
# (('tool', 'intellij'), 5)
# (('tool', 'oracle8'), 4)
# (('tool', 'svn'), 5)
# (('tool', '•'), 6)
# (('traverse', 'document'), 2)
# (('troubleshoot', 'admin'), 2)
# (('troubleshooting', 'ibm'), 3)
# (('tuning', 'clustering'), 2)
# (('tuning', 'troubleshooting'), 3)
# (('tx', 'sep-2016'), 4)
# (('typical', 'n-tier'), 5)
# (('ui', 'gather'), 2)
# (('ui', '•'), 8)
# (('uml', 'design'), 5)
# (('uml', 'methodology'), 2)
# (('uml', 'rational'), 5)
# (('unit', 'test'), 3)
# (('unix', 'commands.java'), 5)
# (('unix', 'linux'), 5)
# (('update', 'portion'), 2)
# (('updated', 'application'), 2)
# (('usage', 'design'), 4)
# (('usage', 'html'), 4)
# (('usage', 'load'), 2)
# (('usage', 'spring'), 4)
# (('usage', 'using'), 3)
# (('user', 'input'), 2)
# (('user', 'interface'), 7)
# (('using', 'admin'), 3)
# (('using', 'adobe'), 2)
# (('using', 'agile'), 8)
# (('using', 'ajax'), 3)
# (('using', 'axis'), 5)
# (('using', 'c++'), 2)
# (('using', 'continuous'), 3)
# (('using', 'd3.js'), 3)
# (('using', 'db2'), 4)
# (('using', 'dom'), 2)
# (('using', 'dreamweaver'), 2)
# (('using', 'firebug'), 2)
# (('using', 'firefox'), 2)
# (('using', 'hibernate'), 10)
# (('using', 'ibm'), 8)
# (('using', 'ides'), 5)
# (('using', 'j2ee'), 4)
# (('using', 'java'), 4)
# (('using', 'java/j2ee'), 5)
# (('using', 'jsp'), 3)
# (('using', 'lightweight'), 4)
# (('using', 'logging'), 5)
# (('using', 'maven'), 7)
# (('using', 'microsoft'), 2)
# (('using', 'mvc'), 5)
# (('using', 'postman'), 4)
# (('using', 'rational'), 5)
# (('using', 'react'), 3)
# (('using', 'react.js'), 3)
# (('using', 'remote'), 2)
# (('using', 'soap'), 5)
# (('using', 'spring'), 12)
# (('using', 'stateless'), 2)
# (('using', 'swing'), 2)
# (('using', 'testing'), 5)
# (('using', 'uml'), 5)
# (('using', 'version'), 5)
# (('using', 'wsad'), 2)
# (('utilized', 'ajax'), 2)
# (('utilized', 'base'), 2)
# (('utilized', 'wsdl'), 2)
# (('v6.0', 'v7.0'), 3)
# (('v7.0', '•'), 3)
# (('validating', 'parsing'), 5)
# (('validation', 'frame'), 4)
# (('validation', 'usage'), 4)
# (('value', 'lab'), 2)
# (('various', 'issue'), 2)
# (('various', 'uml'), 5)
# (('vbscript', 'jstl'), 4)
# (('versed', 'mvc'), 5)
# (('versed', 'using'), 5)
# (('version', 'control'), 6)
# (('vertical', 'clustering'), 3)
# (('view', 'control'), 4)
# (('view', 'controller'), 5)
# (('view', 'helper'), 4)
# (('virtual', 'host'), 2)
# (('visio', '•'), 7)
# (('visualization', 'monitor'), 3)
# (('w3c', 'standard'), 3)
# (('war', 'configured'), 3)
# (('wcag', '2.0'), 3)
# (('web', '2.0'), 4)
# (('web', 'application'), 2)
# (('web', 'browser'), 3)
# (('web', 'container'), 3)
# (('web', 'flow'), 4)
# (('web', 'logic'), 3)
# (('web', 'page'), 8)
# (('web', 'resource'), 2)
# (('web', 'seal'), 2)
# (('web', 'server'), 3)
# (('web', 'service'), 14)
# (('web', 'services-wsdl'), 5)
# (('web', 'sphere'), 14)
# (('web', 'tier'), 6)
# (('web/application', 'server'), 5)
# (('weblogic', 'web'), 5)
# (('webserver', 'log'), 2)
# (('webservices', 'restful'), 3)
# (('webservices.implementationsmethodologies', 'agile'), 4)
# (('website', 'implemented'), 2)
# (('website', '•'), 3)
# (('websphere', 'application'), 6)
# (('websphere', 'commerce'), 6)
# (('websphere', 'portal'), 3)
# (('websphere', 'v6.0'), 3)
# (('websphere', '•'), 2)
# (('wind', 'stream'), 4)
# (('window', '2000'), 5)
# (('window', '2003'), 5)
# (('window', '95/98/nt/2000/xp'), 4)
# (('window', 'c++'), 2)
# (('window', 'linux'), 3)
# (('window', 'xp'), 6)
# (('window', '…'), 5)
# (('wrong', 'database'), 3)
# (('wsad', 'rad'), 2)
# (('wsad', 'toad'), 5)
# (('wscp/wsadmin', 'script'), 3)
# (('wsdl', 'soap'), 2)
# (('xhtml', 'w3c'), 3)
# (('xml', 'apache'), 2)
# (('xml', 'cascading'), 5)
# (('xml', 'cs'), 5)
# (('xml', 'jsp'), 4)
# (('xml', 'schema'), 5)
# (('xml', 'soap'), 3)
# (('xml', 'update'), 2)
# (('xmlspy', 'ant'), 5)
# (('xp', 'window'), 5)
# (('xslt.xml', 'technology'), 5)
# (('•', 'achieved'), 3)
# (('•', 'actively'), 2)
# (('•', 'built'), 3)
# (('•', 'closely'), 2)
# (('•', 'code'), 4)
# (('•', 'core'), 4)
# (('•', 'created'), 13)
# (('•', 'creating'), 3)
# (('•', 'data'), 4)
# (('•', 'debugged'), 2)
# (('•', 'design'), 5)
# (('•', 'designed'), 9)
# (('•', 'developed'), 11)
# (('•', 'experience'), 16)
# (('•', 'experienced'), 30)
# (('•', 'exposure'), 5)
# (('•', 'extjs'), 2)
# (('•', 'gradient'), 4)
# (('•', 'hand'), 5)
# (('•', 'html'), 4)
# (('•', 'ibm'), 4)
# (('•', 'implementation'), 12)
# (('•', 'implemented'), 15)
# (('•', 'installed'), 6)
# (('•', 'involved'), 23)
# (('•', 'javascript'), 2)
# (('•', 'jsf'), 5)
# (('•', 'maintained'), 2)
# (('•', 'mapping'), 4)
# (('•', 'migrated'), 3)
# (('•', 'monitored'), 2)
# (('•', 'one-on-one'), 2)
# (('•', 'platform'), 5)
# (('•', 'prepared'), 3)
# (('•', 'professional'), 5)
# (('•', 'responsible'), 4)
# (('•', 'scripting'), 5)
# (('•', 'serialization'), 4)
# (('•', 'soap'), 2)
# (('•', 'spring'), 4)
# (('•', 'strong'), 10)
# (('•', 'team'), 2)
# (('•', 'technology'), 2)
# (('•', 'testing'), 4)
# (('•', 'troubleshoot'), 2)
# (('•', 'updated'), 2)
# (('•', 'utilized'), 7)
# (('•', 'versed'), 10)
# (('…', 'unix'), 5)
# ['-the-fly configuration',
#  '-till date',
#  '.xml file',
#  '/10g,11g hsql',
#  '1.3 1.4',
#  '1.4 using',
#  '2.0 mobile',
#  '2.0 standard',
#  '2.0.47 ihs',
#  '2.5 mvc',
#  '2000 professional',
#  '2003 server',
#  '2009 technical',
#  '2012 july2014',
#  '2014 aug',
#  '2015 role',
#  '2015–aug 2016',
#  '2016 role',
#  '6.0 apache',
#  '6.0 window',
#  '6.0/6.1 academic',
#  '6.0/6.1 websphere',
#  '6.0/6.1 •',
#  '6.0/6.1/7.0 websphere',
#  '8+ experience',
#  '9.design pattern',
#  '9/10 red',
#  '95/98/nt/2000/xp sun',
#  '9i /10g,11g',
#  'academic bank',
#  'access display',
#  'access manager',
#  'accessibility web',
#  'accommodate advanced',
#  'achieved proficiency',
#  'act front',
#  'actively participated',
#  'add feature',
#  'add modal',
#  'admin console',
#  'admin server',
#  'administered websphere',
#  'adobe flash',
#  'adopted wcag',
#  'advanced fast',
#  'agile methodology',
#  'agile scrum',
#  'ajax increase',
#  'ajax javascript',
#  'analysis design',
#  'analytics using',
#  'angular j',
#  'angular.js development',
#  'angular.js node.js',
#  'angularjs jquery',
#  'ant maven',
#  'ant pl/sq',
#  'anudeep sr',
#  'anudeepreddynallamada gmail.com',
#  'aop spring',
#  'apache 2.0.47',
#  'apache soap',
#  'apache tomcat',
#  'apis analytics',
#  'app management',
#  'app usage',
#  'application access',
#  'application anudeep',
#  'application backbone',
#  'application based',
#  'application code',
#  'application deployment',
#  'application development',
#  'application functionality',
#  'application responding',
#  'application saved',
#  'application server',
#  'application specific',
#  'application usage',
#  'application using',
#  'application web',
#  'application websphere',
#  'application •',
#  'applied industry',
#  'architect back-end',
#  'architect develop',
#  'architecture using',
#  'architecture •',
#  'assemble develop',
#  'aug 2014',
#  'aug 2015',
#  'axis integration',
#  'axis jwsdp',
#  'axis soap',
#  'bachelor engineering',
#  'back-end developer',
#  'backbone j',
#  'backbone.js require.js',
#  'backend service',
#  'bandwidth usage',
#  'bank kansa',
#  'bar ie',
#  'base uml',
#  'based interactive',
#  'based oops',
#  'bean middle',
#  'bean servlets',
#  'bitbucket maven',
#  'boot pl/sql',
#  'boot spring',
#  'browser compatibility',
#  'browser standard',
#  'build management',
#  'build tool',
#  'build using',
#  'building rich',
#  'built data',
#  'built mobile',
#  'business delegate',
#  'business layer',
#  'business logic',
#  'c++ agile',
#  'c++ java/j2ee',
#  'c++ multi-threaded',
#  'car dealership',
#  'cascading style',
#  'change set',
#  'checking jvm',
#  'chrome oracle',
#  'ci/cd jenkins',
#  'city mo',
#  'class diagram',
#  'class framework',
#  'class path',
#  'class sequence',
#  'clean separation',
#  'client contract',
#  'client develop',
#  'client-server architecture',
#  'client-side interface',
#  'client-side javascript',
#  'closely developer',
#  'cloud built',
#  'clustered environment',
#  'clustering performance',
#  'clustering web',
#  'code defect',
#  'code github',
#  'code jdk',
#  'code match',
#  'code modifying',
#  'code review',
#  'code •',
#  'collection developing',
#  'collection multithreading',
#  'color scheme',
#  'commands.java technology',
#  'commerce server',
#  'communicate business',
#  'communication component',
#  'communication dallas',
#  'compatibility accommodate',
#  'component •',
#  'comprehensively test',
#  'computer science',
#  'concept collection',
#  'concurrency exception',
#  'configuration build',
#  'configuration change',
#  'configured administered',
#  'configured application',
#  'conjunction spring',
#  'console wscp/wsadmin',
#  'container parameter',
#  'continuous integration',
#  'contract summarize',
#  'control mvc',
#  'control tool',
#  'controller architecture',
#  'controller session',
#  'controller •',
#  'core dependency',
#  'core java',
#  'core json',
#  'core spring',
#  'created -the-fly',
#  'created build',
#  'created image',
#  'created site',
#  'created user',
#  'created web',
#  'creating java',
#  'cs html',
#  'cs jquery',
#  'cs requirement',
#  'cs spring',
#  'cs style',
#  'cs xml',
#  'cs xslt.xml',
#  'cs •',
#  'css3 etc',
#  'css3 javascript',
#  'css3 shell',
#  'css3 style',
#  'custom tag',
#  'cv •',
#  'cycle initiation',
#  'd3.js jquery',
#  'd3.js mysql',
#  'dallas texassep',
#  'dallas tx',
#  'dao dto',
#  'dao pattern',
#  'dao spring',
#  'data .xml',
#  'data communicate',
#  'data processing',
#  'data storage',
#  'data support',
#  'data using',
#  'data visualization',
#  'database host',
#  'date role',
#  'db spring',
#  'db2 pl/sql',
#  'db2 toad',
#  'dealership website',
#  'debugged application',
#  'decorator factory',
#  'defect deployment',
#  'define configured',
#  'delegate observer',
#  'dependency injection',
#  'deploy java',
#  'deployment class',
#  'deployment ejbs',
#  'deployment error',
#  'design class',
#  'design develop',
#  'design development',
#  'design html5/css3',
#  'design pattern',
#  'design using',
#  'designed apis',
#  'designed dom',
#  'designed frontend',
#  'designing developing',
#  'designing execution',
#  'designing ui',
#  'desktop application',
#  'develop deploy',
#  'develop front-end',
#  'develop layout',
#  'develop solution',
#  'develop test',
#  'developed application',
#  'developed css3',
#  'developed navigation',
#  'developed page',
#  'developed project',
#  'developed using',
#  'developer define',
#  'developer gather',
#  'developer junit',
#  'developer studio',
#  'developer tool',
#  'developing application',
#  'developing n-tier',
#  'developing server-side',
#  'developing user',
#  'developing various',
#  'development cs',
#  'development designing',
#  'development etc',
#  'development life',
#  'development testing',
#  'development tile',
#  'development using',
#  'development •',
#  'development.scripting/gui tool',
#  'dhtml dojo',
#  'dhtml ext',
#  'dhtml xml',
#  'diagram developed',
#  'diagram sequence',
#  'diagram using',
#  'dialog web',
#  'display data',
#  'dml dhtml',
#  'document manipulated',
#  'dojo json',
#  'dom based',
#  'dom dml',
#  'dom dom',
#  'dom function',
#  'dom parsers.ides',
#  'dreamweaver m',
#  'dreamweaver xml',
#  'dreamweaver •',
#  'driven development',
#  'driven development.scripting/gui',
#  'driver servlet',
#  'dtd jaxp',
#  'dto front',
#  'due memory',
#  'dwr log4j.web',
#  'ear war',
#  'eclipse ibm',
#  'eclipse ide',
#  'eclipse netbeans',
#  'eclipse using',
#  'education bachelor',
#  'ee web',
#  'effect developed',
#  'effect development',
#  'ejbs multiple',
#  'elasticsearch logstash',
#  'ember.js d3.js',
#  'engineering computer',
#  'engineering jntu',
#  'engines-as deployment',
#  'enhance application',
#  'enhance portal',
#  'enhanced design',
#  'environment html',
#  'environment html5',
#  'environment java',
#  'environment •',
#  'error wrong',
#  'esb axis',
#  'etc tackled',
#  'etc •',
#  'exception handling',
#  'execution implementation',
#  'exhaustive test',
#  'existing application',
#  'existing code',
#  'experience concurrency',
#  'experience designing',
#  'experience developing',
#  'experience garbage',
#  'experience jsp',
#  'experience using',
#  'experience web/application',
#  'experience wind',
#  'experienced build',
#  'experienced developing',
#  'experienced persistence',
#  'experienced processing',
#  'experienced using',
#  'explorer firefox',
#  'exposure implementing',
#  'ext j',
#  'ext.js •',
#  'extjs building',
#  'extracting data',
#  'factory pattern',
#  'fast technology',
#  'façade business',
#  'feature environment',
#  'file handling',
#  'file server',
#  'file •',
#  'final interface',
#  'financial data',
#  'firebug traverse',
#  'firefox chrome',
#  'firefox ie',
#  'flash photoshop',
#  'flattening object',
#  'flow spring',
#  'frame conjunction',
#  'frame using',
#  'framework angular.js',
#  'framework enhanced',
#  'framework hibernate',
#  'framework implementing',
#  'framework junit',
#  'framework presentation',
#  'framework •',
#  'front controller',
#  'front javascript',
#  'front-end interface',
#  'frontend object',
#  'frontpage vbscript',
#  'function using',
#  'functionality add',
#  'functionality code',
#  'functionality •',
#  'garbage collection',
#  'gather data',
#  'gather requirement',
#  'gathering analysis',
#  'git bitbucket',
#  'github repository',
#  'gmail.com professional',
#  'gradient effect',
#  'graphana git',
#  'gui using',
#  'hand experience',
#  'handling environment',
#  'handling file',
#  'hanging owner',
#  'hat developer',
#  'hat linux',
#  'helper decorator',
#  'hibernate dwr',
#  'hibernate frame',
#  'hibernate hibernate',
#  'hibernate java',
#  'hibernate orm',
#  'hibernate persistence',
#  'horizontal vertical',
#  'host name',
#  'host web',
#  'hsql sybase',
#  'html cs',
#  'html dhtml',
#  'html javascript',
#  'html jsp',
#  'html xhtml',
#  'html •',
#  'html5 css3',
#  'html5 dhtml',
#  'html5/css3 javascript',
#  'hung due',
#  'hyderabad india',
#  'ibm cloud',
#  'ibm dallas',
#  'ibm db2',
#  'ibm mobile',
#  'ibm web',
#  'ibm websphere',
#  'icon applied',
#  'icon layout',
#  'icon web',
#  'ides eclipse',
#  'ie developer',
#  'ie •',
#  'ihs 6.0/6.1',
#  'image logo',
#  'implement web',
#  'implementation business',
#  'implementation clean',
#  'implementation maintenance',
#  'implementation web',
#  'implementation •',
#  'implemented client-side',
#  'implemented final',
#  'implemented horizontal',
#  'implemented mvc',
#  'implemented object-relation',
#  'implemented web',
#  'implementing jstl',
#  'implementing web',
#  'improve speed',
#  'in-browser load',
#  'increase web',
#  'india 2009',
#  'india june',
#  'industry practice',
#  'initiation planning',
#  'injection spring',
#  'injection •',
#  'input request',
#  'insight app',
#  'installed configured',
#  'installed ear',
#  'instance websphere',
#  'instance •',
#  'integration system',
#  'integration tool',
#  'intellij log4j',
#  'interactive reprogram',
#  'interactivity speed',
#  'interface class',
#  'interface design',
#  'interface html',
#  'interface ui',
#  'interface using',
#  'internet application',
#  'internet explorer',
#  'internet intranet',
#  'intranet client-server',
#  'involved application',
#  'involved gui',
#  'involved issue',
#  'involved sdlc',
#  'involved service',
#  'involved stopping/starting',
#  'involved using',
#  'ioc spring',
#  'ireport.operating system',
#  'issue application',
#  'issue checking',
#  'issue java',
#  'issue related',
#  'issue •',
#  'j angular.js',
#  'j eclipse',
#  'j optimize',
#  'j redux',
#  'j require',
#  'j2ee java',
#  'j2ee jsp',
#  'j2ee technology',
#  'java bean',
#  'java code',
#  'java concept',
#  'java cs',
#  'java ee',
#  'java j2ee',
#  'java jsp',
#  'java mail',
#  'java platform',
#  'java programmer',
#  'java script',
#  'java/j2ee pl/sql',
#  'java/j2ee supporting',
#  'java1.8.web technology',
#  'javabeans jndi',
#  'javascript angular.js',
#  'javascript css3',
#  'javascript file',
#  'javascript framework',
#  'javascript html',
#  'javascript jquery',
#  'javascript using',
#  'javascript validation',
#  'javascript xml',
#  'jax-rpc jax-ws',
#  'jax-rs esb',
#  'jax-ws jax-rs',
#  'jaxp sax',
#  'jboss weblogic',
#  'jdbc driver',
#  'jdbc jms',
#  'jdbc spring',
#  'jdk 1.3',
#  'jenkins created',
#  'jenkins.professional experience',
#  'jmockit •',
#  'jms communication',
#  'jms javabeans',
#  'jndi java',
#  'jntu hyderabad',
#  'jquery angular',
#  'jquery dom',
#  'jquery javascript',
#  'jquery mysql',
#  'jquery react.js',
#  'jquery •',
#  'jsf framework',
#  'jsf implementing',
#  'jsf portal',
#  'json javascript',
#  'json servlets',
#  'jsp cs',
#  'jsp java',
#  'jsp jquery',
#  'jsp jsp',
#  'jsp nodejsadditional',
#  'jsp servlet',
#  'jsp spring',
#  'jsp standard',
#  'jsp tag',
#  'jstl java',
#  'jstl jsp',
#  'july2014 role',
#  'june 2012',
#  'junit ireport.operating',
#  'junit jmockit',
#  'jvm log',
#  'jvm setting',
#  'jwsdp restful',
#  'kansa city',
#  'kibana graphana',
#  'lab hyderabad',
#  'lagging •',
#  'language c++',
#  'language javascript',
#  'layer persistent',
#  'layer usage',
#  'layer using',
#  'layout color',
#  'layout navigation',
#  'layout •',
#  'lib jstl',
#  'library custom',
#  'life cycle',
#  'lightweight set',
#  'link adopted',
#  'linux 9.design',
#  'linux platform',
#  'linux •',
#  'load module',
#  'load time',
#  'load web',
#  'log application',
#  'log plug-in',
#  'log webserver',
#  'log •',
#  'log4j jquery',
#  'log4j •',
#  'log4j.web service',
#  'logging tool',
#  'logic application',
#  'logic validation',
#  'logo icon',
#  'logstash kibana',
#  'm frontpage',
#  'm visio',
#  'mail java1.8.web',
#  'maintained security',
#  'maintenance education',
#  'management application',
#  'management insight',
#  'manager •',
#  'manipulated node',
#  'mapping orm',
#  'mapping persistence',
#  'mapping typical',
#  'match front',
#  'maven jenkins.professional',
#  'maven pulled',
#  'maven xmlspy',
#  'maven •',
#  'meet accessibility',
#  'memory thread',
#  'mentoring requirement',
#  'methodology modeled',
#  'methodology scrum',
#  'methodology sdlc',
#  'methodology value',
#  'microsoft visio',
#  'middle tier',
#  'migrated existing',
#  'mo aug',
#  'mobile application',
#  'mobile backend',
#  'mobile •',
#  'mock test',
#  'modal dialog',
#  'model application',
#  'model view',
#  'modeled architect',
#  'modifying existing',
#  'module improve',
#  'mongodb sql',
#  'monitor file',
#  'monitored log',
#  'monitoring log',
#  'monthly financial',
#  'mssql mongodb',
#  'multi-threaded shell',
#  'multiple instance',
#  'multithreading •',
#  'mvc architecture',
#  'mvc business',
#  'mvc core',
#  'mvc dao',
#  'mvc framework',
#  'mvc jsp',
#  'mvc model',
#  'mvc spring',
#  'mvc structure',
#  'mvc •',
#  'mysql db',
#  'mysql mssql',
#  'mysql •',
#  'n-tier application',
#  'n-tier architecture',
#  'name server',
#  'navigation icon',
#  'netbeans rad',
#  'netbeans red',
#  'node using',
#  'node.js backbone.js',
#  'node.js environment',
#  'node.js ext.js',
#  'node.js java',
#  'nodejsadditional skill',
#  'object oriented',
#  'object pooldatabases',
#  'object relational',
#  'object table',
#  'object •',
#  'object-relation mapping',
#  'observer singleton',
#  'one-on-one client',
#  'oops object',
#  'optimize in-browser',
#  'optimize performance',
#  'oracle window',
#  'oracle8 9i',
#  'organize client',
#  'oriented javascript',
#  'oriented programming',
#  'orm object',
#  'orm tool',
#  'owner ship',
#  'page interactivity',
#  'page layout',
#  'page reducing',
#  'page user',
#  'page using',
#  'parameter using',
#  'parsers.ides tool',
#  'parsing extracting',
#  'participated mentoring',
#  'path issue',
#  'pattern factory',
#  'pattern mvc',
#  'pattern pom',
#  'pattern singleton',
#  'pattern •',
#  'performance tuning',
#  'performance using',
#  'persistence framework',
#  'persistence layer',
#  'persistent layer',
#  'phase •',
#  'photoshop dreamweaver',
#  'photoshop •',
#  'pl/sq developer',
#  'pl/sql log4j',
#  'pl/sql query',
#  'pl/sql shell',
#  'planning designing',
#  'platform model',
#  'platform window',
#  'platform •',
#  'plug-in log',
#  'pom object',
#  'pooldatabases tool',
#  'portal framework',
#  'portal server',
#  'portal ui',
#  'portion web',
#  'postman •',
#  'powerful app',
#  'practice standard',
#  'prepared exhaustive',
#  'presentation tier',
#  'processing using',
#  'processing validating',
#  'product using',
#  'professional 8+',
#  'professional summary',
#  'professional window',
#  'proficiency unit',
#  'programmer anudeepreddynallamada',
#  'programmer responsibility',
#  'programming internet',
#  'project code',
#  'project product',
#  'project requirement',
#  'protocol •',
#  'providing client-side',
#  'pulled project',
#  'query •',
#  'rad eclipse',
#  'rad redeployed',
#  'rad wsad',
#  'rad •',
#  'rational rose',
#  'react j',
#  'react.js angular.js',
#  'react.js ember.js',
#  'react.js meet',
#  'red hat',
#  'redeployed clustered',
#  'reducing bandwidth',
#  'redux •',
#  'related browser',
#  'relational mapping',
#  'remote model',
#  'repository •',
#  'reprogram selected',
#  'request •',
#  'require j',
#  'require.js adobe',
#  'requirement enhance',
#  'requirement gathering',
#  'requirement lagging',
#  'resource servlets',
#  'responding application',
#  'responsibility •',
#  'responsible providing',
#  'restful web',
#  'restful webservices.implementationsmethodologies',
#  'review configuration',
#  'rich internet',
#  'role java',
#  'role sr',
#  'rose m',
#  'rose •',
#  'saved node.js',
#  'sax dom',
#  'schema dtd',
#  'scheme website',
#  'science engineering',
#  'script dreamweaver',
#  'script html',
#  'script mysql',
#  'script unix',
#  'script •',
#  'scripting language',
#  'scripting •',
#  'scrum test',
#  'scrum •',
#  'sdlc requirement',
#  'sdlc software',
#  'seal tivoli',
#  'security tuning',
#  'selected link',
#  'sep-2016 -till',
#  'separation layer',
#  'sequence diagram',
#  'serialization flattening',
#  'server 6.0',
#  'server 6.0/6.1',
#  'server 6.0/6.1/7.0',
#  'server apache',
#  'server developer',
#  'server hung',
#  'server ibm',
#  'server instance',
#  'server load',
#  'server speed',
#  'server start-up',
#  'server using',
#  'server virtual',
#  'server websphere',
#  'server window',
#  'server-side service',
#  'server.frameworks strut',
#  'service class',
#  'service desktop',
#  'service optimize',
#  'service powerful',
#  'service specification',
#  'service using',
#  'service •',
#  'services-wsdl using',
#  'servlet act',
#  'servlet engines-as',
#  'servlet jdbc',
#  'servlets developing',
#  'servlets jdbc',
#  'servlets webservices',
#  'session bean',
#  'session façade',
#  'set application',
#  'set tool',
#  'setting web',
#  'sheet cs',
#  'sheet developed',
#  'sheet gradient',
#  'shell script',
#  'shell scripting',
#  'ship issue',
#  'singleton dao',
#  'singleton view',
#  'site organize',
#  'skill elasticsearch',
#  'skill language',
#  'soap hibernate',
#  'soap implement',
#  'soap internet',
#  'soap jms',
#  'soap protocol',
#  'soap soap',
#  'software development',
#  'solaris 9/10',
#  'solution using',
#  'specific jvm',
#  'specification jax-rpc',
#  'speed data',
#  'speed functionality',
#  'speed •',
#  'sphere application',
#  'sphere •',
#  'spring 2.5',
#  'spring aop',
#  'spring boot',
#  'spring core',
#  'spring dao',
#  'spring dependency',
#  'spring framework',
#  'spring hibernate',
#  'spring ioc',
#  'spring jdbc',
#  'spring jsf',
#  'spring mvc',
#  'spring web',
#  'sql server',
#  'sql server.frameworks',
#  'sr java',
#  'standard car',
#  'standard cs',
#  'standard html',
#  'standard project',
#  'standard tag',
#  'start-up issue',
#  'stateless session',
#  'stopping/starting monitoring',
#  'storage using',
#  'stream communication',
#  'strong experience',
#  'structure implementation',
#  'strut spring',
#  'studio rad',
#  'style sheet',
#  'summarize monthly',
#  'summary •',
#  'sun solaris',
#  'support team',
#  'supporting technology',
#  'svn cv',
#  'swing html',
#  'sybase mysql',
#  'system window',
#  'system •',
#  'table using',
#  'tackled various',
#  'tag development',
#  'tag lib',
#  'tag library',
#  'team architect',
#  'team using',
#  'technical skill',
#  'technology angularjs',
#  'technology core',
#  'technology html5',
#  'technology spring',
#  'technology xml',
#  'technology •',
#  'test comprehensively',
#  'test driven',
#  'test functionality',
#  'test html',
#  'test mock',
#  'testing application',
#  'testing framework',
#  'testing phase',
#  'testing web',
#  'texassep 2015–aug',
#  'thread hanging',
#  'tier application',
#  'tier development',
#  'tier servlet',
#  'tile •',
#  'time add',
#  'tivoli access',
#  'toad maven',
#  'toad sql',
#  'tomcat jboss',
#  'tool ant',
#  'tool assemble',
#  'tool bar',
#  'tool ci/cd',
#  'tool eclipse',
#  'tool html5',
#  'tool intellij',
#  'tool oracle8',
#  'tool svn',
#  'tool •',
#  'traverse document',
#  'troubleshoot admin',
#  'troubleshooting ibm',
#  'tuning clustering',
#  'tuning troubleshooting',
#  'tx sep-2016',
#  'typical n-tier',
#  'ui gather',
#  'ui •',
#  'uml design',
#  'uml methodology',
#  'uml rational',
#  'unit test',
#  'unix commands.java',
#  'unix linux',
#  'update portion',
#  'updated application',
#  'usage design',
#  'usage html',
#  'usage load',
#  'usage spring',
#  'usage using',
#  'user input',
#  'user interface',
#  'using admin',
#  'using adobe',
#  'using agile',
#  'using ajax',
#  'using axis',
#  'using c++',
#  'using continuous',
#  'using d3.js',
#  ...]

# %%
#Import scraped data
df = pd.read_csv("final_sample.csv", on_bad_lines='warn', engine="python")
df.head(5)
# Out:
#   JobID                                    job description  \
# 0  J001  TeamSoft is seeing an IT Support Specialist to...
# 1  J002  The Wisconsin State Journal is seeking a flexi...
# 2  J003  Report this job About the Job DePuy Synthes Co...
# 3  J004  Why Join Altec? If you’re considering a career...
# 4  J005  Position ID#  76162 # Positions  1 State  CT C...
#
#                                                title     company overview  \
# 0               IT Support Technician Job in Madison   Full Time Employee
# 1            Business Reporter/Editor Job in Madison            Full Time
# 2  Johnson & Johnson Family of Companies Job Appl...  Full Time, Employee
# 3                    Engineer - Quality Job in Dixon            Full Time
# 4       Shift Supervisor - Part-Time Job in Camphill   Full Time Employee
#
#                                             location  \
# 0                                  Madison, WI 53702
# 1                                  Madison, WI 53708
# 2  DePuy Synthes Companies is a member of Johnson...
# 3                                          Dixon, CA
# 4                                       Camphill, PA
#
#                       organization salary                    industry  \
# 0                              NaN    NaN     IT/Software Development
# 1          Printing and Publishing    NaN                         NaN
# 2  Personal and Household Services    NaN                         NaN
# 3                 Altec Industries    NaN   Experienced (Non-Manager)
# 4                           Retail    NaN  Project/Program Management
#
#                                                  All
# 0  TeamSoft is seeing an IT Support Specialist to...
# 1  The Wisconsin State Journal is seeking a flexi...
# 2  Report this job About the Job DePuy Synthes Co...
# 3  Why Join Altec? If you’re considering a career...
# 4  Position ID#  76162 # Positions  1 State  CT C...

# %%
# print(NLP_Processed_CV)
# print(key_word)
df.shape
# Out:
# (100, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   JobID             100 non-null    object
#  1   job description   100 non-null    object
#  2   title             100 non-null    object
#  3   company overview  93 non-null     object
#  4   location          100 non-null    object
#  5   organization      62 non-null     object
#  6   salary            21 non-null     object
#  7   industry          73 non-null     object
#  8   All               100 non-null    object
# dtypes: object(9)
# memory usage: 7.2+ KB

# %% [markdown]
# # Put keyword/CV into a dataframe

# %%
df2 = pd.DataFrame()
# append columns to an empty DataFrame
df2['title'] = ["I"]
df2['job highlights'] = ["I"]
df2['job description'] = ["I"]
df2['company overview'] = ["I"]
df2['industry'] = ["I"]

# Compare with the key words from CV only
df2['All'] = " ".join(key_word)

# Compare with the entire CV
# df2['All'] = " ".join(NLP_Processed_CV)
# df2

# %% [markdown]
# # Create get_recommendation function

# %%
def get_recommendation(top, df_all, scores):
    recommendation = pd.DataFrame(columns = ['JobID',  'title', 'industry', 'job description','score'])
    count = 0
    for i in top:
#         recommendation.at[count, 'ApplicantID'] = u
        recommendation.at[count, 'JobID'] = df.index[i]
        recommendation.at[count, 'title'] = df['title'][i]
        recommendation.at[count, 'industry'] = df['industry'][i]
#         recommendation.at[count, 'location'] = df['location'][i]
        recommendation.at[count, 'job description'] = df['job description'][i]
        recommendation.at[count, 'score'] =  scores[count]
        count += 1
    return recommendation

# %% [markdown]
# # TFIDF

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer


def TFIDF(scraped_data, cv):
    tfidf_vectorizer = TfidfVectorizer(stop_words='english')

    # TF-IDF Scraped data
    # x = v.fit_transform(df['Review'].apply(lambda x: np.str_(x)))
    tfidf_jobid = tfidf_vectorizer.fit_transform(scraped_data.apply(lambda tfidf_jobid: np.str_(tfidf_jobid)))

    # TF-IDF CV
    user_tfidf = tfidf_vectorizer.transform(cv)

    # Using cosine_similarity on (Scraped data) & (CV)
    cos_similarity_tfidf = map(lambda x: cosine_similarity(user_tfidf,x),tfidf_jobid)

    output2 = list(cos_similarity_tfidf)
    return output2
    
output2 = TFIDF(df['All'], df2['All'])
output2
# Out:
# [array([[0.02657497]]),
#  array([[0.02957909]]),
#  array([[0.05152631]]),
#  array([[0.03468288]]),
#  array([[0.01848572]]),
#  array([[0.06520974]]),
#  array([[0.12129616]]),
#  array([[0.03618113]]),
#  array([[0.01122265]]),
#  array([[0.05104894]]),
#  array([[0.02197753]]),
#  array([[0.01570537]]),
#  array([[0.02041663]]),
#  array([[0.01165873]]),
#  array([[0.02374321]]),
#  array([[0.0437821]]),
#  array([[0.02289673]]),
#  array([[0.04074271]]),
#  array([[0.08792676]]),
#  array([[0.05599213]]),
#  array([[0.08050341]]),
#  array([[0.02445581]]),
#  array([[0.01936605]]),
#  array([[0.06756896]]),
#  array([[0.02655289]]),
#  array([[0.01209288]]),
#  array([[0.05598489]]),
#  array([[0.03971525]]),
#  array([[0.00744881]]),
#  array([[0.04811137]]),
#  array([[0.0547273]]),
#  array([[0.0261201]]),
#  array([[0.06703221]]),
#  array([[0.00446226]]),
#  array([[0.08221048]]),
#  array([[0.07946948]]),
#  array([[0.04819562]]),
#  array([[0.03706975]]),
#  array([[0.08289201]]),
#  array([[0.12608106]]),
#  array([[0.02601251]]),
#  array([[0.01439516]]),
#  array([[0.01185269]]),
#  array([[0.04789855]]),
#  array([[0.01955343]]),
#  array([[0.0079829]]),
#  array([[0.06659783]]),
#  array([[0.04876752]]),
#  array([[0.01904627]]),
#  array([[0.03920465]]),
#  array([[0.03805112]]),
#  array([[0.03593581]]),
#  array([[0.00625529]]),
#  array([[0.17488286]]),
#  array([[0.01777636]]),
#  array([[0.06783027]]),
#  array([[0.01678131]]),
#  array([[0.05723957]]),
#  array([[0.06698108]]),
#  array([[0.01775781]]),
#  array([[0.06248372]]),
#  array([[0.01851018]]),
#  array([[0.02474438]]),
#  array([[0.05502765]]),
#  array([[0.01143846]]),
#  array([[0.03409115]]),
#  array([[0.08035834]]),
#  array([[0.02331738]]),
#  array([[0.02545486]]),
#  array([[0.01479273]]),
#  array([[0.010664]]),
#  array([[0.04742967]]),
#  array([[0.01329114]]),
#  array([[0.05791754]]),
#  array([[0.07089632]]),
#  array([[0.01821282]]),
#  array([[0.03893995]]),
#  array([[0.02501153]]),
#  array([[0.04285675]]),
#  array([[0.01494933]]),
#  array([[0.04233003]]),
#  array([[0.05137346]]),
#  array([[0.02396308]]),
#  array([[0.05834272]]),
#  array([[0.0260646]]),
#  array([[0.02496728]]),
#  array([[0.04899213]]),
#  array([[0.06166626]]),
#  array([[0.0420555]]),
#  array([[0.071532]]),
#  array([[0.04729588]]),
#  array([[0.03474456]]),
#  array([[0.029997]]),
#  array([[0.10134091]]),
#  array([[0.07857946]]),
#  array([[0.20561641]]),
#  array([[0.05219735]]),
#  array([[0.05219306]]),
#  array([[0.05370453]]),
#  array([[0.02679195]])]

# %%
top = sorted(range(len(output2)), key=lambda i: output2[i], reverse=True)[:100]
list_scores = [output2[i][0][0] for i in top]
TF=get_recommendation(top,df, list_scores)
TF
# Out:
#    JobID                                              title  \
# 0     95                         Scrum Master Job in Denver
# 1     53                Software Engineer Job in Fort Wayne
# 2     39  Software Engineer - Display Solutions Group Jo...
# 3      6  CyberCoders Job Application for Principal QA E...
# 4     93      Custom Development Engineer Job in Greenville
# ..   ...                                                ...
# 95    70   Hotel Construction Superintendent Job in Houston
# 96    45  Respiratory Therapist PRN Nights - Kindred Hos...
# 97    28                           Resident Care Specialist
# 98    52  Elementary English Language Acquisition – Span...
# 99    33                   Equipment Operator Job in Denver
#
#                    industry  \
# 0   IT/Software Development
# 1               Engineering
# 2                       NaN
# 3                       NaN
# 4               Engineering
# ..                      ...
# 95                      NaN
# 96           Medical/Health
# 97                      NaN
# 98                      NaN
# 99                      NaN
#
#                                       job description     score
# 0   The Judge Group is looking for a Scrum Master ...  0.205616
# 1   A Fortune 500 and worldwide leader in business...  0.174883
# 2   ResponsibilitiesCandidate will participate in ...  0.126081
# 3   Report this job About the Job Based in San Fra...  0.121296
# 4   About Agfa HealthCare   Agfa HealthCare, a mem...  0.101341
# ..                                                ...       ...
# 95  Houston based General Contractor with 20 years...  0.010664
# 96  Respiratory Therapist PRN Nights - Kindred Hos...  0.007983
# 97  Resident Care Specialist DescriptionSummaryPro...  0.007449
# 98  Elementary English  Language Acquisition – Spa...  0.006255
# 99  Construction                                  ...  0.004462
#
# [100 rows x 5 columns]

# %% [markdown]
# # Count Vectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

count_vectorizer = CountVectorizer()
count_jobid = count_vectorizer.fit_transform(df['All'].apply(lambda count_jobid: np.str_(count_jobid))) #fitting and transforming the vector
count_jobid
# Out:
# <100x5243 sparse matrix of type '<class 'numpy.int64'>'
# 	with 20060 stored elements in Compressed Sparse Row format>

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def count_vectorize(scraped_data, cv):
    # CountV the scraped data
    count_vectorizer = CountVectorizer()
    count_jobid = count_vectorizer.fit_transform(scraped_data.apply(lambda count_jobid: np.str_(count_jobid))) #fitting and transforming the vector

    # CountV the cv
    user_count = count_vectorizer.transform(cv)
    cos_similarity_countv = map(lambda x: cosine_similarity(user_count, x),count_jobid)
    output3 = list(cos_similarity_countv)
    return output3
output3 = count_vectorize(df['All'], df2['All'])
output3
# Out:
# [array([[0.05133426]]),
#  array([[0.04552007]]),
#  array([[0.06051582]]),
#  array([[0.04533373]]),
#  array([[0.0316139]]),
#  array([[0.07473813]]),
#  array([[0.13205722]]),
#  array([[0.04571678]]),
#  array([[0.02922354]]),
#  array([[0.05219548]]),
#  array([[0.04158535]]),
#  array([[0.03187833]]),
#  array([[0.03605834]]),
#  array([[0.0255263]]),
#  array([[0.04271993]]),
#  array([[0.05683885]]),
#  array([[0.03322121]]),
#  array([[0.04456734]]),
#  array([[0.07753377]]),
#  array([[0.05203844]]),
#  array([[0.0901623]]),
#  array([[0.03986846]]),
#  array([[0.03196113]]),
#  array([[0.04781308]]),
#  array([[0.04593086]]),
#  array([[0.03442472]]),
#  array([[0.05503198]]),
#  array([[0.04674823]]),
#  array([[0.01789144]]),
#  array([[0.06184268]]),
#  array([[0.08725511]]),
#  array([[0.05381022]]),
#  array([[0.05665558]]),
#  array([[0.03034671]]),
#  array([[0.07724833]]),
#  array([[0.06886401]]),
#  array([[0.05901206]]),
#  array([[0.04904167]]),
#  array([[0.08619283]]),
#  array([[0.14358917]]),
#  array([[0.04908942]]),
#  array([[0.03551261]]),
#  array([[0.02537112]]),
#  array([[0.06859063]]),
#  array([[0.03170121]]),
#  array([[0.01947448]]),
#  array([[0.05425586]]),
#  array([[0.06309452]]),
#  array([[0.0558455]]),
#  array([[0.05282097]]),
#  array([[0.04815934]]),
#  array([[0.06587981]]),
#  array([[0.01671398]]),
#  array([[0.12526696]]),
#  array([[0.04352036]]),
#  array([[0.07365832]]),
#  array([[0.02927197]]),
#  array([[0.05454406]]),
#  array([[0.06500714]]),
#  array([[0.01926336]]),
#  array([[0.05149725]]),
#  array([[0.0371835]]),
#  array([[0.03394761]]),
#  array([[0.06625041]]),
#  array([[0.03879703]]),
#  array([[0.04513729]]),
#  array([[0.08242185]]),
#  array([[0.04217283]]),
#  array([[0.02355882]]),
#  array([[0.03544739]]),
#  array([[0.0363983]]),
#  array([[0.06741233]]),
#  array([[0.0433121]]),
#  array([[0.06630721]]),
#  array([[0.07544187]]),
#  array([[0.04436583]]),
#  array([[0.06658265]]),
#  array([[0.05358639]]),
#  array([[0.05593714]]),
#  array([[0.03750683]]),
#  array([[0.07360378]]),
#  array([[0.04950444]]),
#  array([[0.05204944]]),
#  array([[0.09961546]]),
#  array([[0.03321785]]),
#  array([[0.03701026]]),
#  array([[0.0578993]]),
#  array([[0.05038301]]),
#  array([[0.05442035]]),
#  array([[0.07868398]]),
#  array([[0.07486671]]),
#  array([[0.05818946]]),
#  array([[0.04885437]]),
#  array([[0.13047481]]),
#  array([[0.11711181]]),
#  array([[0.20903277]]),
#  array([[0.07293496]]),
#  array([[0.05739597]]),
#  array([[0.07075945]]),
#  array([[0.04376204]])]

# %%
# print(count_jobid)

# %%
user_count = count_vectorizer.transform(df2['All'])
user_count
# Out:
# <1x5243 sparse matrix of type '<class 'numpy.int64'>'
# 	with 269 stored elements in Compressed Sparse Row format>

# %%
print(user_count)
# Out:
#   (0, 16)	2
#   (0, 68)	4
#   (0, 71)	2
#   (0, 73)	2
#   (0, 74)	4
#   (0, 75)	4
#   (0, 236)	2
#   (0, 245)	4
#   (0, 249)	2
#   (0, 283)	2
#   (0, 289)	2
#   (0, 302)	4
#   (0, 329)	3
#   (0, 336)	2
#   (0, 375)	5
#   (0, 438)	2
#   (0, 443)	2
#   (0, 474)	4
#   (0, 480)	43
#   (0, 512)	6
#   (0, 539)	2
#   (0, 637)	5
#   (0, 641)	2
#   (0, 645)	2
#   (0, 654)	2
#   :	:
#   (0, 4773)	2
#   (0, 4894)	2
#   (0, 4895)	2
#   (0, 4918)	2
#   (0, 4933)	2
#   (0, 4961)	2
#   (0, 4966)	4
#   (0, 4975)	2
#   (0, 4978)	2
#   (0, 4979)	2
#   (0, 4997)	10
#   (0, 5002)	5
#   (0, 5005)	73
#   (0, 5009)	4
#   (0, 5021)	2
#   (0, 5022)	4
#   (0, 5028)	2
#   (0, 5036)	4
#   (0, 5053)	3
#   (0, 5067)	5
#   (0, 5076)	3
#   (0, 5107)	2
#   (0, 5128)	41
#   (0, 5129)	4
#   (0, 5167)	14

# %%
cos_similarity_countv = map(lambda x: cosine_similarity(user_count, x),count_jobid)
output3 = list(cos_similarity_countv)
# output3

# %%
# output3 = count_vectorize(df['All'], df2['All'])
# output3

# %%
top = sorted(range(len(output3)), key=lambda i: output3[i], reverse=True)[:100]
list_scores = [output3[i][0][0] for i in top]
cv=get_recommendation(top, df, list_scores)
cv
# Out:
#    JobID                                              title  \
# 0     95                         Scrum Master Job in Denver
# 1     39  Software Engineer - Display Solutions Group Jo...
# 2      6  CyberCoders Job Application for Principal QA E...
# 3     93      Custom Development Engineer Job in Greenville
# 4     53                Software Engineer Job in Fort Wayne
# ..   ...                                                ...
# 95    68          Local/Delivery Truck Driver Job in Denver
# 96    45  Respiratory Therapist PRN Nights - Kindred Hos...
# 97    59      Technical Writer - Documentation Job in Ogden
# 98    28                           Resident Care Specialist
# 99    52  Elementary English Language Acquisition – Span...
#
#                      industry  \
# 0     IT/Software Development
# 1                         NaN
# 2                         NaN
# 3                 Engineering
# 4                 Engineering
# ..                        ...
# 95  Experienced (Non-Manager)
# 96             Medical/Health
# 97          Editorial/Writing
# 98                        NaN
# 99                        NaN
#
#                                       job description     score
# 0   The Judge Group is looking for a Scrum Master ...  0.209033
# 1   ResponsibilitiesCandidate will participate in ...  0.143589
# 2   Report this job About the Job Based in San Fra...  0.132057
# 3   About Agfa HealthCare   Agfa HealthCare, a mem...  0.130475
# 4   A Fortune 500 and worldwide leader in business...  0.125267
# ..                                                ...       ...
# 95  Job Purpose:Delivers items by preparing, loadi...  0.023559
# 96  Respiratory Therapist PRN Nights - Kindred Hos...  0.019474
# 97  Maden Technologies is accepting applications f...  0.019263
# 98  Resident Care Specialist DescriptionSummaryPro...  0.017891
# 99  Elementary English  Language Acquisition – Spa...  0.016714
#
# [100 rows x 5 columns]

# %% [markdown]
# # KNN

# %%
# !pip uninstall scikit-learn -y
# !pip install scikit-learn==0.24.1

# %%
from sklearn.neighbors import NearestNeighbors

def KNN(scraped_data, cv):
    tfidf_vectorizer = TfidfVectorizer(stop_words='english')

    # n_neighbors = 100
    KNN = NearestNeighbors(n_neighbors=100, p=2)
    #  count_jobid = count_vectorizer.fit_transform(scraped_data.apply(lambda count_jobid: np.str_(count_jobid))) 
    x= tfidf_vectorizer.fit_transform(scraped_data.apply(lambda x: np.str_(x)))
    KNN.fit(x)
    # KNN.fit(tfidf_vectorizer.fit_transform(scraped_data))
#     NNs = KNN.kneighbors(tfidf_vectorizer.transform(cv), return_distance=True)
    NNs = KNN.kneighbors(tfidf_vectorizer.transform(cv))
    top = NNs[1][0][1:]
    index_score = NNs[0][0][1:]

    knn = get_recommendation(top, df, index_score)
    return knn

knn = KNN(df['All'], df2['All'])
knn
# Out:
#    JobID                                              title  \
# 0     53                Software Engineer Job in Fort Wayne
# 1     39  Software Engineer - Display Solutions Group Jo...
# 2      6  CyberCoders Job Application for Principal QA E...
# 3     93      Custom Development Engineer Job in Greenville
# 4     18  Content Developer for MATLAB Code Generation J...
# ..   ...                                                ...
# 94    70   Hotel Construction Superintendent Job in Houston
# 95    45  Respiratory Therapist PRN Nights - Kindred Hos...
# 96    28                           Resident Care Specialist
# 97    52  Elementary English Language Acquisition – Span...
# 98    33                   Equipment Operator Job in Denver
#
#                      industry  \
# 0                 Engineering
# 1                         NaN
# 2                         NaN
# 3                 Engineering
# 4   Experienced (Non-Manager)
# ..                        ...
# 94                        NaN
# 95             Medical/Health
# 96                        NaN
# 97                        NaN
# 98                        NaN
#
#                                       job description     score
# 0   A Fortune 500 and worldwide leader in business...  1.284614
# 1   ResponsibilitiesCandidate will participate in ...  1.322058
# 2   Report this job About the Job Based in San Fra...  1.325673
# 3   About Agfa HealthCare   Agfa HealthCare, a mem...  1.340641
# 4   Job SummaryDo you have a strong aptitude for w...   1.35061
# ..                                                ...       ...
# 94  Houston based General Contractor with 20 years...  1.406653
# 95  Respiratory Therapist PRN Nights - Kindred Hos...  1.408557
# 96  Resident Care Specialist DescriptionSummaryPro...  1.408937
# 97  Elementary English  Language Acquisition – Spa...  1.409783
# 98  Construction                                  ...  1.411055
#
# [99 rows x 5 columns]

# %%
knn.to_csv('knn.csv', index=False)

# %% [markdown]
# # Combined TFIDF, CV and KNN result together, to make a dataframe "final"

# %%
# merge1 = knn[['JobID','title', 'score']].merge(TF[['JobID','score']], on= "JobID")
# final = merge1.merge(cv[['JobID','score']], on = "JobID")
# final = final.rename(columns={"score_x": "KNN", "score_y": "TF-IDF","score": "CV"})
# final.head()

merge1 = knn[['JobID','title', 'score']].merge(TF[['JobID','score']], on= "JobID")
final = merge1.merge(cv[['JobID','score']], on = "JobID")
final = final.rename(columns={"score_x": "KNN", "score_y": "TF-IDF","score": "CV"})
final.head()
# Out:
#   JobID                                              title       KNN  \
# 0    53                Software Engineer Job in Fort Wayne  1.284614
# 1    39  Software Engineer - Display Solutions Group Jo...  1.322058
# 2     6  CyberCoders Job Application for Principal QA E...  1.325673
# 3    93      Custom Development Engineer Job in Greenville  1.340641
# 4    18  Content Developer for MATLAB Code Generation J...   1.35061
#
#      TF-IDF        CV
# 0  0.174883  0.125267
# 1  0.126081  0.143589
# 2  0.121296  0.132057
# 3  0.101341  0.130475
# 4  0.087927  0.077534

# %%
# high = max(knn['score'])
# def reverseScoring(df, high, cols):
#     '''Reverse scores on given columns
#      df = your data frame,
#      high = highest score available
#      cols = the columns you want reversed in list form'''
#     df[cols] = high - df[cols]
# #     return df['score']
#     return df
# reverseScoring(knn, high, 'score')

# %%
# reverseScoring(knn, high, 'score').to_csv('test.csv', index=False)

# %% [markdown]
# # Scale and assign weights

# %%
# Scale it
from sklearn.preprocessing import MinMaxScaler
slr = MinMaxScaler()
# round(final['KNN'],9)
final[["KNN", "TF-IDF", 'CV']] = slr.fit_transform(final[["KNN", "TF-IDF", 'CV']])

# Multiply by weights
final['KNN'] = (1-final['KNN'])/3
final['TF-IDF'] = final['TF-IDF']/3
final['CV'] = final['CV']/3
final['Final'] = final['KNN']+final['TF-IDF']+final['CV']
final.sort_values(by="Final", ascending=False)
# Out:
#    JobID                                              title       KNN  \
# 0     53                Software Engineer Job in Fort Wayne  0.333333
# 1     39  Software Engineer - Display Solutions Group Jo...  0.234621
# 2      6  CyberCoders Job Application for Principal QA E...  0.225092
# 3     93      Custom Development Engineer Job in Greenville  0.185631
# 10    94               Electrical Engineer Job in Budd Lake  0.141152
# ..   ...                                                ...       ...
# 91    13  Primrose Private Preschool Teacher Job in Houston  0.013470
# 98    33                   Equipment Operator Job in Denver  0.000000
# 95    45  Respiratory Therapist PRN Nights - Kindred Hos...  0.006583
# 96    28                           Resident Care Specialist  0.005584
# 97    52  Elementary English Language Acquisition – Span...  0.003351
#
#       TF-IDF        CV     Final
# 0   0.333333  0.285196  0.951863
# 1   0.237880  0.333333  0.805834
# 2   0.228521  0.303036  0.756649
# 3   0.189489  0.298879  0.673999
# 10  0.144969  0.263771  0.549892
# ..       ...       ...       ...
# 91  0.014076  0.023152  0.050698
# 98  0.000000  0.035817  0.035817
# 95  0.006886  0.007253  0.020722
# 96  0.005842  0.003093  0.014519
# 97  0.003507  0.000000  0.006859
#
# [99 rows x 6 columns]

# %%
# final.to_csv('final.csv', index=False)
final2 = final.sort_values(by="Final", ascending=False).copy()
final2
# Out:
#    JobID                                              title       KNN  \
# 0     53                Software Engineer Job in Fort Wayne  0.333333
# 1     39  Software Engineer - Display Solutions Group Jo...  0.234621
# 2      6  CyberCoders Job Application for Principal QA E...  0.225092
# 3     93      Custom Development Engineer Job in Greenville  0.185631
# 10    94               Electrical Engineer Job in Budd Lake  0.141152
# ..   ...                                                ...       ...
# 91    13  Primrose Private Preschool Teacher Job in Houston  0.013470
# 98    33                   Equipment Operator Job in Denver  0.000000
# 95    45  Respiratory Therapist PRN Nights - Kindred Hos...  0.006583
# 96    28                           Resident Care Specialist  0.005584
# 97    52  Elementary English Language Acquisition – Span...  0.003351
#
#       TF-IDF        CV     Final
# 0   0.333333  0.285196  0.951863
# 1   0.237880  0.333333  0.805834
# 2   0.228521  0.303036  0.756649
# 3   0.189489  0.298879  0.673999
# 10  0.144969  0.263771  0.549892
# ..       ...       ...       ...
# 91  0.014076  0.023152  0.050698
# 98  0.000000  0.035817  0.035817
# 95  0.006886  0.007253  0.020722
# 96  0.005842  0.003093  0.014519
# 97  0.003507  0.000000  0.006859
#
# [99 rows x 6 columns]

# %%
final2.head(10)
# Out:
#    JobID                                              title       KNN  \
# 0     53                Software Engineer Job in Fort Wayne  0.333333
# 1     39  Software Engineer - Display Solutions Group Jo...  0.234621
# 2      6  CyberCoders Job Application for Principal QA E...  0.225092
# 3     93      Custom Development Engineer Job in Greenville  0.185631
# 10    94               Electrical Engineer Job in Budd Lake  0.141152
# 7     20         Business & Strategy Analyst Job in Houston  0.144890
# 5     38  Bi-Lingual Editorial Strategist Job in San Fra...  0.149537
# 4     18  Content Developer for MATLAB Code Generation J...  0.159351
# 8     66               Development Associate Job in Houston  0.144608
# 6     34     Associate Product Developer Job in Saint Louis  0.148210
#
#       TF-IDF        CV     Final
# 0   0.333333  0.285196  0.951863
# 1   0.237880  0.333333  0.805834
# 2   0.228521  0.303036  0.756649
# 3   0.189489  0.298879  0.673999
# 10  0.144969  0.263771  0.549892
# 7   0.148732  0.192967  0.486590
# 5   0.153404  0.182539  0.485480
# 4   0.163252  0.159789  0.482392
# 8   0.148449  0.172631  0.465688
# 6   0.152071  0.159039  0.459321

# %%
# duplicate = df[df.duplicated()]
# duplicate
# a = np.intersect1d(df.columns, final2.columns)
# a

# %%
final2.merge(df, on="JobID")
# final_salary = df.merge(final2, on="JobID")
final_salary
# Out:
# Empty DataFrame
# Columns: [JobID, job description, title_x, company overview, location, organization, salary, industry, All, title_y, KNN, TF-IDF, CV, Final]
# Index: []
